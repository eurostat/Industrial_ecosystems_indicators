# %%
# pandas
import pandas as pd

# %%
import PySimpleGUI as sg
def selection(option):
    #sg.theme('DarkAmber')   # Add a touch of color
    #select the variable we want to calculate
    options = option

    # All the stuff inside your window.
    layout = [ 
            [sg.Text('Select one->'), sg.Listbox(options,select_mode=sg.LISTBOX_SELECT_MODE_SINGLE,size=(20,len(options)))],
            [sg.Button('Ok'), sg.Button('Cancel')]
        ]

    # Create the Window
    window = sg.Window('Make your choice', layout)

    # Event Loop to process "events" and get the "values" of the input
    while True:
        event, values = window.read()
        print( f"event={event}" )
        if event is None or event == 'Ok' or event == 'Cancel': # if user closes window or clicks cancel
            break
        
    # close  the window        
    window.close()

    if event == "Cancel":
        print( "You cancelled" )
    else:
        print('You entered ', values[0])
        sg.popup( f"You selected {values[0]}" )        
    return values

# %%
import eurostat
df = eurostat.get_data_df('bd_9ac_l_form_r2', flags=False)
df
# Out:
#        indic_sb leg_form nace_r2 geo\time    2020    2019    2018    2017  \
# 0        V11910   ENT_LL       B       AT  181.00  180.00  179.00  183.00
# 1        V11910   ENT_LL       B       BA     NaN  246.00  252.00  249.00
# 2        V11910   ENT_LL       B       BE  149.00  151.00  137.00  176.00
# 3        V11910   ENT_LL       B       BG  282.00  271.00  333.00  343.00
# 4        V11910   ENT_LL       B       CH     NaN  235.00  238.00  241.00
# ...         ...      ...     ...      ...     ...     ...     ...     ...
# 449584   V97131    TOTAL     S96       RO    1.29    1.23    1.39    1.47
# 449585   V97131    TOTAL     S96       SI    0.98     NaN    1.04    1.05
# 449586   V97131    TOTAL     S96       SK    1.02    1.13    1.20    1.15
# 449587   V97131    TOTAL     S96       TR     NaN     NaN    1.48    1.40
# 449588   V97131    TOTAL     S96       UK     NaN     NaN    3.03    2.87
#
#           2016    2015  ...    2013    2012    2011    2010    2009    2008  \
# 0       183.00  186.00  ...  189.00  195.00  197.00  195.00  196.00  199.00
# 1          NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2       186.00  194.00  ...  210.00  218.00  230.00  232.00  232.00  254.00
# 3       379.00  395.00  ...  400.00  378.00  356.00  361.00  359.00  291.00
# 4       240.00  242.00  ...  252.00     NaN     NaN     NaN     NaN     NaN
# ...        ...     ...  ...     ...     ...     ...     ...     ...     ...
# 449584    1.27    1.31  ...    1.04    1.42    1.12    1.29    1.42    1.75
# 449585    0.99    1.00  ...    1.05    1.00     NaN     NaN     NaN     NaN
# 449586     NaN    1.14  ...    1.09    1.17    1.05    1.06    1.06     NaN
# 449587    1.55    1.51  ...    1.48    1.55    1.95    1.76    1.49     NaN
# 449588    2.79    3.03  ...    2.93    2.68    2.73    2.51    2.47    2.50
#
#          2007   2006   2005   2004
# 0       192.0  165.0  162.0  160.0
# 1         NaN    NaN    NaN    NaN
# 2         NaN    NaN    NaN    NaN
# 3         NaN    NaN    NaN    NaN
# 4         NaN    NaN    NaN    NaN
# ...       ...    ...    ...    ...
# 449584    NaN    NaN    NaN    NaN
# 449585    NaN    NaN    NaN    NaN
# 449586    NaN    NaN    NaN    NaN
# 449587    NaN    NaN    NaN    NaN
# 449588    NaN    NaN    NaN    NaN
#
# [449589 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['indic_sb', 'leg_form',  'nace_r2', 'geo\time',       2020,       2019,
#              2018,       2017,       2016,       2015,       2014,       2013,
#              2012,       2011,       2010,       2009,       2008,       2007,
#              2006,       2005,       2004],
#       dtype='object')

# %%
#eliminate columns for years previous to 2011
years =[]
year_start=2004
year_study=2011
for y in range(year_start,year_study): 
    years.append(y)
df=df.drop(years, axis=1)#quitamos todas las columnas de añosque no nos interesan
#rename geo time column to be easier to handle because of the name
df.rename(columns={"geo\\time": "geo"}, inplace=True)
#We can get the unique values of the different variables

# %%
df
# Out:
#        indic_sb leg_form nace_r2 geo    2020    2019    2018    2017    2016  \
# 0        V11910   ENT_LL       B  AT  181.00  180.00  179.00  183.00  183.00
# 1        V11910   ENT_LL       B  BA     NaN  246.00  252.00  249.00     NaN
# 2        V11910   ENT_LL       B  BE  149.00  151.00  137.00  176.00  186.00
# 3        V11910   ENT_LL       B  BG  282.00  271.00  333.00  343.00  379.00
# 4        V11910   ENT_LL       B  CH     NaN  235.00  238.00  241.00  240.00
# ...         ...      ...     ...  ..     ...     ...     ...     ...     ...
# 449584   V97131    TOTAL     S96  RO    1.29    1.23    1.39    1.47    1.27
# 449585   V97131    TOTAL     S96  SI    0.98     NaN    1.04    1.05    0.99
# 449586   V97131    TOTAL     S96  SK    1.02    1.13    1.20    1.15     NaN
# 449587   V97131    TOTAL     S96  TR     NaN     NaN    1.48    1.40    1.55
# 449588   V97131    TOTAL     S96  UK     NaN     NaN    3.03    2.87    2.79
#
#           2015    2014    2013    2012    2011
# 0       186.00  186.00  189.00  195.00  197.00
# 1          NaN     NaN     NaN     NaN     NaN
# 2       194.00  201.00  210.00  218.00  230.00
# 3       395.00  388.00  400.00  378.00  356.00
# 4       242.00  247.00  252.00     NaN     NaN
# ...        ...     ...     ...     ...     ...
# 449584    1.31    1.45    1.04    1.42    1.12
# 449585    1.00     NaN    1.05    1.00     NaN
# 449586    1.14    1.05    1.09    1.17    1.05
# 449587    1.51    1.50    1.48    1.55    1.95
# 449588    3.03    2.98    2.93    2.68    2.73
#
# [449589 rows x 14 columns]

# %%
weights_target = pd.read_excel("ecosystemweights.xlsx")
naceweights=weights_target['NACE_R2'].unique()
naceweights
# Out:
# array(['A', 'C10-C12', 'C13-C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21', 'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29',
#        'C30', 'C31', 'C32', 'C33', 'D', 'E36', 'E37-E39', 'F', 'G45',
#        'G46', 'G47', 'H49', 'H50', 'H51', 'H52', 'H53', 'I', 'J58',
#        'J59_J60', 'J61', 'J62_J63', 'L', 'M69_M70', 'M71', 'M72', 'M73',
#        'M74_M75', 'N77', 'N78', 'N79', 'N80', 'N81', 'N82', 'P', 'Q86',
#        'Q87_Q88', 'R90-R92', 'R93', 'S94', 'S95', 'S96', 'T'],
#       dtype=object)

# %%
nacedf=df['nace_r2'].unique()
nacedf
# Out:
# array(['B', 'B-E', 'B-N_X_K642', 'B-S_X_K642', 'C', 'C10-C12', 'C13_C14',
#        'C15', 'C16', 'C17_C18', 'C19', 'C20_C21', 'C22', 'C23', 'C24_C25',
#        'C26_C27', 'C28', 'C29_C30', 'C31_C32', 'C33', 'C_ICT', 'D', 'E',
#        'F', 'G', 'G-N_X_K642', 'G-U_ICT', 'G45', 'G46', 'G46_ICT', 'G47',
#        'G471', 'G472', 'G473', 'G474', 'G475', 'G476', 'G477', 'G478',
#        'G479', 'H', 'H49', 'H50', 'H51', 'H52', 'H53', 'I', 'I55', 'I56',
#        'ICT', 'J', 'J58', 'J59', 'J60', 'J61', 'J62', 'J620', 'J6201',
#        'J6202', 'J6203', 'J6209', 'J63', 'K64_X_K642', 'K65', 'K66',
#        'K_X_K642', 'L', 'L68', 'L681', 'L6810', 'L682', 'L6820', 'L683',
#        'L6831', 'L6832', 'M', 'M69', 'M691', 'M6910', 'M692', 'M6920',
#        'M70', 'M701', 'M7010', 'M702', 'M7021', 'M7022', 'M71', 'M711',
#        'M7111', 'M7112', 'M712', 'M7120', 'M72', 'M721', 'M7211', 'M7219',
#        'M722', 'M7220', 'M73', 'M731', 'M7311', 'M7312', 'M732', 'M7320',
#        'M74', 'M741', 'M7410', 'M742', 'M7420', 'M743', 'M7430', 'M749',
#        'M7490', 'M75', 'M750', 'M7500', 'N', 'N77', 'N771', 'N7711',
#        'N7712', 'N772', 'N7721', 'N7722', 'N7729', 'N773', 'N7731',
#        'N7732', 'N7733', 'N7734', 'N7735', 'N7739', 'N774', 'N7740',
#        'N78', 'N781', 'N7810', 'N782', 'N7820', 'N783', 'N7830', 'N79',
#        'N791', 'N7911', 'N7912', 'N799', 'N7990', 'N80', 'N801', 'N8010',
#        'N802', 'N8020', 'N803', 'N8030', 'N81', 'N811', 'N8110', 'N812',
#        'N8121', 'N8122', 'N8129', 'N813', 'N8130', 'N82', 'N821', 'N8211',
#        'N8219', 'N822', 'N8220', 'N823', 'N8230', 'N829', 'N8291',
#        'N8292', 'N8299', 'P', 'P-S', 'P-S_X_S94', 'P85', 'Q', 'Q86',
#        'Q87', 'Q88', 'R', 'R90', 'R91', 'R92', 'R93', 'S', 'S94', 'S95',
#        'S96', 'TOTAL'], dtype=object)

# %%
nace_sel=[]
for n in naceweights:
    if n in nacedf:
        nace_sel.append(n)
nace_sel
# Out:
# ['C10-C12',
#  'C16',
#  'C19',
#  'C22',
#  'C23',
#  'C28',
#  'C33',
#  'D',
#  'F',
#  'G45',
#  'G46',
#  'G47',
#  'H49',
#  'H50',
#  'H51',
#  'H52',
#  'H53',
#  'I',
#  'J58',
#  'J61',
#  'L',
#  'M71',
#  'M72',
#  'M73',
#  'N77',
#  'N78',
#  'N79',
#  'N80',
#  'N81',
#  'N82',
#  'P',
#  'Q86',
#  'R93',
#  'S94',
#  'S95',
#  'S96']

# %%
nace_dif=set(naceweights)-set(nace_sel)
nace_dif
# Out:
# {'A',
#  'C13-C15',
#  'C17',
#  'C18',
#  'C20',
#  'C21',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C29',
#  'C30',
#  'C31',
#  'C32',
#  'E36',
#  'E37-E39',
#  'J59_J60',
#  'J62_J63',
#  'M69_M70',
#  'M74_M75',
#  'Q87_Q88',
#  'R90-R92',
#  'T'}

# %%
nace_include=['C13_C14','C15', 'C17_C18', 'C20_C21', 'C24_C25',  'C26_C27',  'C29_C30', 'C31_C32','E', 'J59', 'J60', 'J62', 'J63',
'M69','M70', 'M74', 'M75', 'Q87', 'Q88', 'R90', 'R91', 'R92']
nace_include
# Out:
# ['C13_C14',
#  'C15',
#  'C17_C18',
#  'C20_C21',
#  'C24_C25',
#  'C26_C27',
#  'C29_C30',
#  'C31_C32',
#  'E',
#  'J59',
#  'J60',
#  'J62',
#  'J63',
#  'M69',
#  'M70',
#  'M74',
#  'M75',
#  'Q87',
#  'Q88',
#  'R90',
#  'R91',
#  'R92']

# %%
nace_def=[]
for n in nace_include:
    nace_sel.append(n)
nace_sel
# Out:
# ['C10-C12',
#  'C16',
#  'C19',
#  'C22',
#  'C23',
#  'C28',
#  'C33',
#  'D',
#  'F',
#  'G45',
#  'G46',
#  'G47',
#  'H49',
#  'H50',
#  'H51',
#  'H52',
#  'H53',
#  'I',
#  'J58',
#  'J61',
#  'L',
#  'M71',
#  'M72',
#  'M73',
#  'N77',
#  'N78',
#  'N79',
#  'N80',
#  'N81',
#  'N82',
#  'P',
#  'Q86',
#  'R93',
#  'S94',
#  'S95',
#  'S96',
#  'C13_C14',
#  'C15',
#  'C17_C18',
#  'C20_C21',
#  'C24_C25',
#  'C26_C27',
#  'C29_C30',
#  'C31_C32',
#  'E',
#  'J59',
#  'J60',
#  'J62',
#  'J63',
#  'M69',
#  'M70',
#  'M74',
#  'M75',
#  'Q87',
#  'Q88',
#  'R90',
#  'R91',
#  'R92']

# %% [raw]
# [V11910] Population of active enterprises in t - number
# [V11920] Births of enterprises in t - number
# [V11930] Deaths of enterprises in t - number
# [V97015] Business churn: birth rate + death rate - percentage
# [V97020] Birth rate: number of enterprise births in the reference period (t) divided by the tota

# %%
#list of selected variables variabales

indic_sb=['V11910']
legform=['TOTAL']

# %%
df.columns
# Out:
# Index(['indic_sb', 'leg_form',  'nace_r2',      'geo',       2020,       2019,
#              2018,       2017,       2016,       2015,       2014,       2013,
#              2012,       2011],
#       dtype='object')

# %%
nacedrop=['O','K66', 'J', 'H', 'C16-C18','A03', 'O-Q', 'E', 'C31-C33', 'M_N', 'J58-J60', 'R-U', 'G', 'K', 'TOTAL', 'L68A', 'A02', 'C22_C23', 'C29_C30',  'B-E', 'G-I', 'N', 'Q', 'R', 'C24_C25','C', 'M69-M71', 'M73-M75', 'U', 'S', 'B', 'M', 'A01', 'K65','K64']
countries_not_selected= ['UK', 'TR', 'AL','IS','LI','NO','CH','UK','ME','MK','AL','RS','TR','BA','EU28','EU15','EA','EA19','EA12', 'EU27_2007' ,'EU_V']

#we select the rows that have the right unit, nace codes, items and countries
df_selection=df[df.nace_r2.isin(nace_sel)&df.leg_form.isin(legform)&df.indic_sb.isin(indic_sb)&~df.geo.isin(countries_not_selected)]
df_selection.set_index('nace_r2', inplace=True)
df_selection
# Out:
#         indic_sb leg_form geo     2020     2019     2018     2017     2016  \
# nace_r2
# C10-C12   V11910    TOTAL  AT   4629.0   4525.0   4579.0   4474.0   4448.0
# C10-C12   V11910    TOTAL  BE   7791.0   7704.0   7536.0   7772.0   7693.0
# C10-C12   V11910    TOTAL  BG   5925.0   6170.0   6317.0   6424.0   6503.0
# C10-C12   V11910    TOTAL  CY    945.0    939.0    834.0    929.0    906.0
# C10-C12   V11910    TOTAL  CZ  11719.0  11324.0  10882.0  10330.0   9816.0
# ...          ...      ...  ..      ...      ...      ...      ...      ...
# S96       V11910    TOTAL  PL      NaN      NaN      NaN      NaN      NaN
# S96       V11910    TOTAL  PT  58543.0  58748.0  55619.0  53420.0  50842.0
# S96       V11910    TOTAL  RO  40652.0  37272.0  34165.0  31843.0  28602.0
# S96       V11910    TOTAL  SI   7559.0   7358.0   7028.0   6706.0   6659.0
# S96       V11910    TOTAL  SK  19386.0  18620.0  17830.0  16635.0  15114.0
#
#             2015     2014     2013     2012     2011
# nace_r2
# C10-C12   4400.0   4442.0   4549.0   4757.0   4806.0
# C10-C12   7659.0   7687.0   7809.0   7893.0   8079.0
# C10-C12   6393.0   6200.0   6017.0   5820.0   5694.0
# C10-C12    902.0    907.0    897.0    912.0    888.0
# C10-C12   9393.0   9108.0  10532.0   9614.0   9215.0
# ...          ...      ...      ...      ...      ...
# S96          NaN      NaN      NaN      NaN      NaN
# S96      49180.0  47629.0  47144.0  47570.0  50124.0
# S96      26871.0  25144.0  24227.0  28476.0  18611.0
# S96       6413.0   6088.0   5784.0   5542.0   5331.0
# S96      14136.0  13904.0  10376.0  10574.0  10536.0
#
# [1601 rows x 13 columns]

# %%
#ratios to disaggregate values based on number of entrerprises
ratios_values = pd.read_excel("ratio-Enterprises - number.xlsx")
ratios_values.set_index('nace_r2', inplace=True)#nace as index
ratios_values
# Out:
#          Enterprises - number2011  Enterprises - number2012  \
# nace_r2
# C17                      0.142719                  0.144014
# C18                      0.857281                  0.855986
# C20                      0.876293                  0.878456
# C21                      0.123707                  0.121544
# C24                      0.044613                  0.042943
# C25                      0.955387                  0.957057
# C26                      0.431176                  0.430538
# C27                      0.568824                  0.569462
# C29                      0.579390                  0.585392
# C30                      0.420610                  0.414608
# C31                      0.469565                  0.461590
# C32                      0.530435                  0.538410
# E36                      0.228697                  0.212448
# E37                      0.157496                  0.153549
# E38                      0.578893                  0.594444
# E39                      0.034914                  0.039559
#
#          Enterprises - number2013  Enterprises - number2014  \
# nace_r2
# C17                      0.142813                  0.141727
# C18                      0.857187                  0.858273
# C20                      0.874083                  0.879588
# C21                      0.125917                  0.120412
# C24                      0.043057                  0.040022
# C25                      0.956943                  0.959978
# C26                      0.439708                  0.439024
# C27                      0.560292                  0.560976
# C29                      0.585427                  0.583907
# C30                      0.414573                  0.416093
# C31                      0.450009                  0.439626
# C32                      0.549991                  0.560374
# E36                      0.214071                  0.209534
# E37                      0.151875                  0.150071
# E38                      0.593034                  0.599621
# E39                      0.041021                  0.040774
#
#          Enterprises - number2015  Enterprises - number2016  \
# nace_r2
# C17                      0.142321                  0.146802
# C18                      0.857679                  0.853198
# C20                      0.886641                  0.868502
# C21                      0.113359                  0.131498
# C24                      0.039473                  0.038860
# C25                      0.960527                  0.961140
# C26                      0.441048                  0.439283
# C27                      0.558952                  0.560717
# C29                      0.570094                  0.573379
# C30                      0.429906                  0.426621
# C31                      0.440000                  0.450866
# C32                      0.560000                  0.549134
# E36                      0.212841                  0.205711
# E37                      0.141894                  0.150854
# E38                      0.595956                  0.591596
# E39                      0.049308                  0.051839
#
#          Enterprises - number2017  Enterprises - number2018  \
# nace_r2
# C17                      0.145963                  0.154977
# C18                      0.854037                  0.845023
# C20                      0.888041                  0.890197
# C21                      0.111959                  0.109803
# C24                      0.037579                  0.035533
# C25                      0.962421                  0.964467
# C26                      0.447368                  0.462338
# C27                      0.552632                  0.537662
# C29                      0.564660                  0.557615
# C30                      0.435340                  0.442385
# C31                      0.443378                  0.444444
# C32                      0.556622                  0.555556
# E36                      0.202028                  0.196796
# E37                      0.154703                  0.149552
# E38                      0.590684                  0.600123
# E39                      0.052585                  0.053529
#
#          Enterprises - number2019
# nace_r2
# C17                      0.147746
# C18                      0.852254
# C20                      0.886870
# C21                      0.113130
# C24                      0.036274
# C25                      0.963726
# C26                      0.463051
# C27                      0.536949
# C29                      0.557139
# C30                      0.442861
# C31                      0.447100
# C32                      0.552900
# E36                      0.187755
# E37                      0.150742
# E38                      0.605433
# E39                      0.056071

# %%
# columns of countries to be eliminated
cols = ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI','FR', 'HR', 'HU', 'IE', 'IT', 'LT','LU', 'LV', 'MT','NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
pd.set_option('display.float_format', lambda x: '%.0f' % x)
#create a dataframe for the results
results_compiled = pd.DataFrame()
variable_of_interest='Enterprises population'

import numpy as np
#loop to calculate values for years
for j in range (2011,2019):
    year=j
    #we transpose the values for the year selected
    for i in range (year,year+1):
        df_target = pd.pivot_table(df_selection, values=i, index=['nace_r2'],columns=["geo"], aggfunc=np.sum, fill_value=0)#reorde
    df_target['sum'] = df_target[cols].sum(axis=1)#sums the columns of the countries to "sum" 
    df_target=df_target.drop(cols, axis=1)#eliminamos las columnas sumadas de países
    df_target.loc[df_target['EU27_2020']==0,'EU27_2020'] = df_target['sum']#now we can locate columns with 0 and make the substitution with the column "sum"
    moddf_target=df_target.drop('sum', axis=1)#we create a new table 
        #add rows C31,... and assign value with the ratio multiplying by the value of position C31_32
    year_ratio=j-2011
    moddf_target.loc['C13-C15'] = moddf_target.loc['C13_C14']+moddf_target.loc['C15']
    moddf_target.loc['J59_J60'] = moddf_target.loc['J59']+moddf_target.loc['J60']
    moddf_target.loc['J62_J63'] = moddf_target.loc['J62']+moddf_target.loc['J63']
    moddf_target.loc['M69_M70'] = moddf_target.loc['M69']+moddf_target.loc['M70']
    moddf_target.loc['M74_M75'] = moddf_target.loc['M74']+moddf_target.loc['M75']
    moddf_target.loc['Q87_Q88'] = moddf_target.loc['Q87']+moddf_target.loc['Q88']    
    moddf_target.loc['R90-R92'] = moddf_target.loc['R90']+moddf_target.loc['R91']+moddf_target.loc['R92'] 
    moddf_target.loc['C17'] = ratios_values.iloc[0][year_ratio]*moddf_target.loc['C17_C18','EU27_2020']
    moddf_target.loc['C18'] = ratios_values.iloc[1][year_ratio]*moddf_target.loc['C17_C18','EU27_2020']
    moddf_target.loc['C20'] = ratios_values.iloc[2][year_ratio]*moddf_target.loc['C20_C21','EU27_2020']
    moddf_target.loc['C21'] = ratios_values.iloc[3][year_ratio]*moddf_target.loc['C20_C21','EU27_2020']
    moddf_target.loc['C24'] = ratios_values.iloc[4][year_ratio]*moddf_target.loc['C24_C25','EU27_2020']
    moddf_target.loc['C25'] = ratios_values.iloc[5][year_ratio]*moddf_target.loc['C24_C25','EU27_2020']
    moddf_target.loc['C26'] = ratios_values.iloc[6][year_ratio]*moddf_target.loc['C26_C27','EU27_2020']
    moddf_target.loc['C27'] = ratios_values.iloc[7][year_ratio]*moddf_target.loc['C26_C27','EU27_2020']
    moddf_target.loc['C29'] = ratios_values.iloc[8][year_ratio]*moddf_target.loc['C29_C30','EU27_2020']
    moddf_target.loc['C30'] = ratios_values.iloc[9][year_ratio]*moddf_target.loc['C29_C30','EU27_2020']
    moddf_target.loc['C31'] = ratios_values.iloc[10][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
    moddf_target.loc['C32'] = ratios_values.iloc[11][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
    moddf_target.loc['E36'] = ratios_values.iloc[12][year_ratio]*moddf_target.loc['E','EU27_2020']
    moddf_target.loc['E37-E39'] = (1-ratios_values.iloc[12][year_ratio])*moddf_target.loc['E','EU27_2020']
    #we eliminate old rows
    moddf_target = moddf_target.drop(['C17_C18', 'C20_C21','C24_C25', 'C26_C27', 'C29_C30', 'C31_C32', 'E','C13_C14', 'C15','C20_C21','J59','J60', 'J62','J63', 'M69','M70', 'M74','M75', 'Q87','Q88','R90', 'R91','R92'])
    
    weights_target = pd.read_excel("ecosystemweights.xlsx")
    weights_target.set_index('NACE_R2', inplace=True)#nace como índice
    column_name=str(variable_of_interest)+str(year)
    weights_target[variable_of_interest]=weights_target.index.map(moddf_target['EU27_2020'])#busca en df_target el nace y copia el valor de EU27_2020 en la fila del nace the weights_target
    #creamos la matriz de resultados
    results=weights_target
    for i in range(0,14):
        results.iloc[:, i]=weights_target.iloc[:, i]*weights_target[variable_of_interest]#we multiply the total value added by the weight for each nace
    results.loc['total'] = results.select_dtypes(pd.np.number).sum() #we add the values of each colum in a row call total
    results_compiled[column_name]=results.loc['total']
results_compiled = results_compiled.drop(variable_of_interest)

#results_compiled.loc['total'] = results_compiled.select_dtypes(pd.np.number).sum()
results_compiled
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:53: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                Enterprises population2011  \
# Aerospace & Defence                                                283626
# Agri-food                                                          574369
# Construction                                                      5569773
# Cultural and Creative Industries                                  1713866
# Digital                                                           1013599
# Electronics                                                        102086
# Energy - Renewables                                                 94863
# Energy Intensive Industries                                        573137
# Health                                                            1940468
# Mobility - Transport - Automotive                                 1763605
# Proximity, Social Economy and Civil Security                      2577386
# Retail                                                            5954031
# Textile                                                            271808
# Tourism                                                           3451256
#
#                                                Enterprises population2012  \
# Aerospace & Defence                                                294431
# Agri-food                                                          610537
# Construction                                                      5743358
# Cultural and Creative Industries                                  1785967
# Digital                                                           1069843
# Electronics                                                        105482
# Energy - Renewables                                                106218
# Energy Intensive Industries                                        586702
# Health                                                            2013373
# Mobility - Transport - Automotive                                 1855587
# Proximity, Social Economy and Civil Security                      2676112
# Retail                                                            6199440
# Textile                                                            280914
# Tourism                                                           3648125
#
#                                                Enterprises population2013  \
# Aerospace & Defence                                                293288
# Agri-food                                                          614244
# Construction                                                      5701793
# Cultural and Creative Industries                                  1814707
# Digital                                                           1096598
# Electronics                                                        104760
# Energy - Renewables                                                107917
# Energy Intensive Industries                                        579335
# Health                                                            2027019
# Mobility - Transport - Automotive                                 1867164
# Proximity, Social Economy and Civil Security                      2717984
# Retail                                                            6180101
# Textile                                                            279471
# Tourism                                                           3707574
#
#                                                Enterprises population2014  \
# Aerospace & Defence                                                297534
# Agri-food                                                          620206
# Construction                                                      5792562
# Cultural and Creative Industries                                  1886604
# Digital                                                           1146059
# Electronics                                                        107268
# Energy - Renewables                                                109321
# Energy Intensive Industries                                        592723
# Health                                                            2100683
# Mobility - Transport - Automotive                                 1891616
# Proximity, Social Economy and Civil Security                      2788384
# Retail                                                            6194156
# Textile                                                            284260
# Tourism                                                           3798011
#
#                                                Enterprises population2015  \
# Aerospace & Defence                                                300017
# Agri-food                                                          627190
# Construction                                                      5824930
# Cultural and Creative Industries                                  1949542
# Digital                                                           1178569
# Electronics                                                        107531
# Energy - Renewables                                                111614
# Energy Intensive Industries                                        590709
# Health                                                            2235292
# Mobility - Transport - Automotive                                 1911729
# Proximity, Social Economy and Civil Security                      2883705
# Retail                                                            6152106
# Textile                                                            285125
# Tourism                                                           3889008
#
#                                                Enterprises population2016  \
# Aerospace & Defence                                                303202
# Agri-food                                                          635091
# Construction                                                      5901444
# Cultural and Creative Industries                                  1998080
# Digital                                                           1213868
# Electronics                                                        107654
# Energy - Renewables                                                114517
# Energy Intensive Industries                                        584989
# Health                                                            2296553
# Mobility - Transport - Automotive                                 1940270
# Proximity, Social Economy and Civil Security                      2930222
# Retail                                                            6105084
# Textile                                                            287050
# Tourism                                                           3972676
#
#                                                Enterprises population2017  \
# Aerospace & Defence                                                312107
# Agri-food                                                          647039
# Construction                                                      6021463
# Cultural and Creative Industries                                  2052370
# Digital                                                           1287014
# Electronics                                                        109287
# Energy - Renewables                                                116236
# Energy Intensive Industries                                        593246
# Health                                                            2346136
# Mobility - Transport - Automotive                                 1986637
# Proximity, Social Economy and Civil Security                      2974999
# Retail                                                            6079778
# Textile                                                            290686
# Tourism                                                           4070688
#
#                                                Enterprises population2018
# Aerospace & Defence                                                313733
# Agri-food                                                          654705
# Construction                                                      6168989
# Cultural and Creative Industries                                  2123008
# Digital                                                           1317840
# Electronics                                                        111095
# Energy - Renewables                                                114484
# Energy Intensive Industries                                        593082
# Health                                                            2381647
# Mobility - Transport - Automotive                                 2008897
# Proximity, Social Economy and Civil Security                      3011285
# Retail                                                            6032453
# Textile                                                            293229
# Tourism                                                           4159412

# %%
moddf_target.index
# Out:
# Index(['C10-C12', 'C16', 'C19', 'C22', 'C23', 'C28', 'C33', 'D', 'F', 'G45',
#        'G46', 'G47', 'H49', 'H50', 'H51', 'H52', 'H53', 'I', 'J58', 'J61', 'L',
#        'M71', 'M72', 'M73', 'N77', 'N78', 'N79', 'N80', 'N81', 'N82', 'P',
#        'Q86', 'R93', 'S94', 'S95', 'S96', 'C13-C15', 'J59_J60', 'J62_J63',
#        'M69_M70', 'M74_M75', 'Q87_Q88', 'R90-R92', 'C17', 'C18', 'C20', 'C21',
#        'C24', 'C25', 'C26', 'C27', 'C29', 'C30', 'C31', 'C32', 'E36',
#        'E37-E39'],
#       dtype='object', name='nace_r2')

# %%
weights_target.index
# Out:
# Index(['A', 'C10-C12', 'C13-C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21',
#        'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29', 'C30', 'C31',
#        'C32', 'C33', 'D', 'E36', 'E37-E39', 'F', 'G45', 'G46', 'G47', 'H49',
#        'H50', 'H51', 'H52', 'H53', 'I', 'J58', 'J59_J60', 'J61', 'J62_J63',
#        'L', 'M69_M70', 'M71', 'M72', 'M73', 'M74_M75', 'N77', 'N78', 'N79',
#        'N80', 'N81', 'N82', 'P', 'Q86', 'Q87_Q88', 'R90-R92', 'R93', 'S94',
#        'S95', 'S96', 'T', 'total'],
#       dtype='object', name='NACE_R2')

# %%
diferencia_nace=set(weights_target.index)-set(moddf_target.index)
diferencia_nace
# Out:
# {'A', 'T', 'total'}

# %%
#save to file
filename = "%s.xlsx" % variable_of_interest
results_compiled.to_excel(filename)
