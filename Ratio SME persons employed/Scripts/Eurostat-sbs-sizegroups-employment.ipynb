# %%
#pip install PySimpleGUI

# %%
# pandas
import pandas as pd 
# pip install eurostat  #herramienta para importar datos de eurostat
import eurostat
df = eurostat.get_data_df('sbs_sc_sca_r2', flags=False)
df
# Out:
#        nace_r2 indic_sb size_emp geo\time  2020   2019   2018   2017   2016  \
# 0            B   V11110      0-9       AT   NaN  183.0  192.0  215.0  226.0
# 1            B   V11110      0-9       BA   NaN  101.0  102.0  121.0  129.0
# 2            B   V11110      0-9       BE   NaN  140.0  118.0  173.0  144.0
# 3            B   V11110      0-9       BG   NaN  190.0  211.0  215.0  224.0
# 4            B   V11110      0-9       CH   NaN   82.0   84.0   81.0   85.0
# ...        ...      ...      ...      ...   ...    ...    ...    ...    ...
# 475052     S95   V92100    TOTAL       RS   NaN    4.4    4.3    4.2    4.2
# 475053     S95   V92100    TOTAL       SE   NaN    1.1    1.1    1.2    1.2
# 475054     S95   V92100    TOTAL       SI   NaN    1.5    1.5    1.5    1.5
# 475055     S95   V92100    TOTAL       SK   NaN    1.5    1.4    1.5    1.4
# 475056     S95   V92100    TOTAL       UK   NaN    NaN    5.2    4.4    7.3
#
#          2015   2014   2013   2012   2011   2010   2009   2008  2007  2006  \
# 0       230.0  227.0  238.0  238.0  242.0  245.0  244.0  237.0   NaN   NaN
# 1       132.0  121.0  118.0  121.0  150.0    NaN    NaN    NaN   NaN   NaN
# 2       167.0  149.0  175.0  160.0  227.0  249.0  248.0    NaN   NaN   NaN
# 3       240.0  228.0  243.0  252.0  245.0  241.0  230.0  199.0   NaN   NaN
# 4        84.0   86.0   89.0   75.0   75.0   79.0   85.0    NaN   NaN   NaN
# ...       ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 475052    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 475053    1.2    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 475054    1.5    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 475055    1.4    1.3    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
# 475056    6.1    NaN    NaN    NaN    NaN    NaN    NaN    NaN   NaN   NaN
#
#         2005
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 475052   NaN
# 475053   NaN
# 475054   NaN
# 475055   NaN
# 475056   NaN
#
# [475057 rows x 20 columns]

# %%
#eliminate columns for years previous to 2011
years =[]
for y in range(2005,2011): 
    years.append(y)
df=df.drop(years, axis=1)#quitamos todas las columnas de añosque no nos interesan
#rename geo time column to be easier to handle because of the name
df.rename(columns={"geo\\time": "geo"}, inplace=True)
#We can get the unique values of the different variables

# %%
import PySimpleGUI as sg
def selection(option):
    #sg.theme('DarkAmber')   # Add a touch of color
    #select the variable we want to calculate
    options = option

    # All the stuff inside your window.
    layout = [ 
            [sg.Text('Select one->'), sg.Listbox(options,select_mode=sg.LISTBOX_SELECT_MODE_SINGLE,size=(20,len(options)))],
            [sg.Button('Ok'), sg.Button('Cancel')]
        ]

    # Create the Window
    window = sg.Window('Make your choice', layout)

    # Event Loop to process "events" and get the "values" of the input
    while True:
        event, values = window.read()
        print( f"event={event}" )
        if event is None or event == 'Ok' or event == 'Cancel': # if user closes window or clicks cancel
            break
        
    # close  the window        
    window.close()

    if event == "Cancel":
        print( "You cancelled" )
    else:
        print('You entered ', values[0])
        sg.popup( f"You selected {values[0]}" )        
    return values

# %%
dic_item = eurostat.get_dic('indic_sb') #dictionary for all the indicators in sbs in eurostat
for item in df.indic_sb.unique():
    if item in dic_item:
        print (item + " -"+dic_item[item])
var=selection(df.indic_sb.unique())[0]
# Out:
# V11110 -Enterprises - number
# V12110 -Turnover or gross premiums written - million euro
# V12120 -Production value - million euro
# V12150 -Value added at factor cost - million euro
# V12170 -Gross operating surplus - million euro
# V13110 -Total purchases of goods and services - million euro
# V13310 -Personnel costs - million euro
# V13320 -Wages and Salaries - million euro
# V13330 -Social security costs - million euro
# V16110 -Persons employed - number
# V16120 -Unpaid persons employed - number
# V16130 -Employees - number
# V16150 -Hours worked by employees - number
# V91100 -Turnover per person employed - thousand euro
# V91110 -Apparent labour productivity (Gross value added per person employed) - thousand euro
# V91120 -Wage adjusted labour productivity (Apparent labour productivity by average personnel costs) - percentage
# V91130 -Gross value added per employee - thousand euro
# V91150 -Gross value added per hour worked by employees
# V91170 -Share of personnel costs in production - percentage
# V91210 -Average personnel costs (personnel costs per employee) - thousand euro
# V91230 -Labour cost per hour worked by employees
# V91275 -Share of employees in persons employed - percentage
# V91290 -Growth rate of employment - percentage
# V91310 -Employer's social charges as a percentage of personnel costs - percentage
# V92100 -Persons employed per enterprise - number
# V92110 -Gross operating surplus/turnover (gross operating rate) - percentage
# V92111 -Value added at factor cost in production value - percentage
# V92112 -Share of personnel costs in total purchases of goods and services - percentage
# V94210 -Share of value added in manufacturing total - percentage
# V94240 -Share of production value in manufacturing total - percentage
# V94270 -Share of turnover in manufacturing total - percentage
# V94310 -Share of employment in manufacturing total - percentage
# event=Ok
# You entered  ['V16110']

# %%
#determine the variable of interest based on the selection
for item in var:
    if item in dic_item:
        variable_of_interest=dic_item[item]
variable_of_interest
# Out:
# 'Persons employed - number'

# %% [raw]
# #selection of the variable
# list_of_variables = pd.read_excel("variabledescription.xlsx")
# var=selection(df.indic_sb.unique())[0]
# condition=list_of_variables[list_of_variables["variable"]==var[0]]
# variable_of_interest=condition.iloc[0]['description']
# print(variable_of_interest)
# print(" ")
# #var=values #with [] we convert variable to a list to apply "isin"
# print(var)

# %%
#sedlect the size
#size_sel=selection(df.size_emp.unique())[0] #with [] we convert variable to a list to apply "isin"
#print(size_sel)



#select de year frame
yearsloop =[]
for y in range(2011,2021): 
    yearsloop.append(y)
year_start=selection(yearsloop)[0] #with [] we convert variable to a list to apply "isin"
year_end=selection(yearsloop)[0]
print(year_start)
print(year_end)
# Out:
# event=Ok
# You entered  [2011]
# event=Ok
# You entered  [2019]
# [2011]
# [2019]

# %%
#list of countries available
countries=df.geo.unique()
print("Countries", countries)
print(" ")
#list of variables available
variables=df.indic_sb.unique()
print("Variables", variables)
print(" ")
#see size groups
size=df.size_emp.unique()
print("Size",size)
print(" ")
#load weights database
weights_target = pd.read_excel("ecosystemweightsextended.xlsx")
#check nace groups in weights
naceweights=weights_target.NACE_R2.unique()
nace_groups={'C10-C12','C13-C15', 'E37-E39','J59_J60','J62_J63','M74_M75', 'N77_N78', 'D35'}
naceweights=set(naceweights)-set(nace_groups)
#check nace groups in the database
nacedatabase=df.nace_r2.unique()
#look for the differences to eliminate nace codes
nacedrop=set(nacedatabase)-set(naceweights)
print("Nace weights",naceweights)
print(" ")
print("Nace database",nacedatabase)
print(" ")
print("Nace to drop",nacedrop)
print(" ")
#countries to eliminate
countries_not_selected= ['UK', 'TR', 'AL','IS','LI','NO','CH','UK','ME','MK','AL','RS','TR','BA','EU28','EU15','EA','EA19','EA12', 'EU27_2007']
print(countries_not_selected)
print(" ")
#select the size we want to evaluate
# Out:
# Countries ['AT' 'BA' 'BE' 'BG' 'CH' 'CY' 'CZ' 'DE' 'DK' 'EE' 'EL' 'ES' 'EU27_2007'
#  'EU27_2020' 'EU28' 'FI' 'FR' 'HR' 'HU' 'IE' 'IS' 'IT' 'LT' 'LU' 'LV' 'MK'
#  'MT' 'NL' 'NO' 'PL' 'PT' 'RO' 'RS' 'SE' 'SI' 'SK' 'UK' 'AL' 'TR']
#
# Variables ['V11110' 'V12110' 'V12120' 'V12150' 'V12170' 'V13110' 'V13310' 'V13320'
#  'V13330' 'V16110' 'V16120' 'V16130' 'V16150' 'V91100' 'V91110' 'V91120'
#  'V91130' 'V91150' 'V91170' 'V91210' 'V91230' 'V91275' 'V91290' 'V91310'
#  'V92100' 'V92110' 'V92111' 'V92112' 'V94210' 'V94240' 'V94270' 'V94310']
#
# Size ['0-9' '10-19' '20-49' '50-249' 'GE250' 'TOTAL']
#
# Nace weights {'P85', 'N77', 'J63', 'C12', 'C23', 'L', 'A', 'J61', 'G46', 'R90-R92', 'E36', 'J62', 'C10', 'E37', 'T', 'C14', 'N79', 'C29', 'H53', 'C33', 'Q87_Q88', 'R93', 'H49', 'C20', 'M69_M70', 'C15', 'C27', 'N81', 'M69', 'M72', 'G47', 'H50', 'P', 'J60', 'N82', 'Q86', 'C18', 'F', 'J59', 'C28', 'M71', 'S96', 'J58', 'S94', 'C25', 'M70', 'C16', 'C17', 'G45', 'C11', 'E38', 'S95', 'M74', 'C24', 'C19', 'C30', 'H52', 'C32', 'C13', 'I', 'N80', 'H51', 'N78', 'E39', 'C21', 'D', 'C22', 'C26', 'C31', 'M75', 'M73'}
#
# Nace database ['B' 'B-N_S95_X_K' 'B05' 'B051' 'B052' 'B06' 'B061' 'B062' 'B07' 'B071'
#  'B072' 'B08' 'B081' 'B089' 'B09' 'B091' 'B099' 'C' 'C10' 'C101' 'C102'
#  'C103' 'C104' 'C105' 'C106' 'C107' 'C108' 'C109' 'C11' 'C110' 'C12'
#  'C120' 'C13' 'C131' 'C132' 'C133' 'C139' 'C14' 'C141' 'C142' 'C143' 'C15'
#  'C151' 'C152' 'C16' 'C161' 'C162' 'C17' 'C171' 'C172' 'C18' 'C181' 'C182'
#  'C19' 'C191' 'C192' 'C20' 'C201' 'C202' 'C203' 'C204' 'C205' 'C206' 'C21'
#  'C211' 'C212' 'C22' 'C221' 'C222' 'C23' 'C231' 'C232' 'C233' 'C234'
#  'C235' 'C236' 'C237' 'C239' 'C24' 'C241' 'C242' 'C243' 'C244' 'C245'
#  'C25' 'C251' 'C252' 'C253' 'C254' 'C255' 'C256' 'C257' 'C259' 'C26'
#  'C261' 'C262' 'C263' 'C264' 'C265' 'C266' 'C267' 'C268' 'C27' 'C271'
#  'C272' 'C273' 'C274' 'C275' 'C279' 'C28' 'C281' 'C282' 'C283' 'C284'
#  'C289' 'C29' 'C291' 'C292' 'C293' 'C30' 'C301' 'C302' 'C303' 'C304'
#  'C309' 'C31' 'C310' 'C32' 'C321' 'C322' 'C323' 'C324' 'C325' 'C329' 'C33'
#  'C331' 'C332' 'D' 'D35' 'D351' 'D352' 'D353' 'E' 'E36' 'E360' 'E37'
#  'E370' 'E38' 'E381' 'E382' 'E383' 'E39' 'E390' 'F' 'F41' 'F411' 'F412'
#  'F42' 'F421' 'F422' 'F429' 'F43' 'F431' 'F432' 'F433' 'F439' 'G' 'G45'
#  'G46' 'G47' 'H' 'H49' 'H50' 'H51' 'H52' 'H53' 'I' 'I55' 'I56' 'J' 'J58'
#  'J59' 'J60' 'J61' 'J62' 'J63' 'L' 'L68' 'M' 'M69' 'M70' 'M71' 'M72' 'M73'
#  'M74' 'M75' 'N' 'N77' 'N78' 'N79' 'N80' 'N81' 'N82' 'S95']
#
# Nace to drop {'C142', 'C222', 'C133', 'C273', 'C206', 'M', 'C329', 'I55', 'C304', 'C263', 'E383', 'C331', 'B089', 'F43', 'E381', 'B061', 'C232', 'C120', 'I56', 'B062', 'C324', 'B09', 'C191', 'B051', 'C162', 'B05', 'C259', 'C302', 'F41', 'D352', 'C282', 'C203', 'C309', 'B052', 'C301', 'C245', 'C103', 'B', 'J', 'C221', 'C332', 'F411', 'C152', 'C325', 'C323', 'D353', 'C293', 'C262', 'C281', 'E382', 'B08', 'E', 'C161', 'C110', 'C182', 'C171', 'C201', 'C204', 'C102', 'C', 'B07', 'C234', 'D351', 'C244', 'C132', 'E390', 'E360', 'C104', 'F431', 'C101', 'C211', 'C212', 'C271', 'D35', 'C105', 'B-N_S95_X_K', 'C109', 'C241', 'C272', 'C310', 'C279', 'C255', 'B071', 'B091', 'C242', 'C268', 'C274', 'C267', 'C106', 'C261', 'C275', 'C292', 'C143', 'C141', 'C231', 'C257', 'C283', 'C265', 'C205', 'F432', 'H', 'C253', 'B099', 'B06', 'C322', 'L68', 'C108', 'F439', 'C237', 'F42', 'N', 'C139', 'E370', 'C303', 'F429', 'C233', 'C181', 'C256', 'C236', 'C131', 'C284', 'C289', 'F433', 'G', 'F422', 'C266', 'C264', 'C192', 'C235', 'F421', 'C321', 'C239', 'C172', 'C254', 'C202', 'F412', 'C151', 'C251', 'C107', 'C252', 'C243', 'B081', 'B072', 'C291'}
#
# ['UK', 'TR', 'AL', 'IS', 'LI', 'NO', 'CH', 'UK', 'ME', 'MK', 'AL', 'RS', 'TR', 'BA', 'EU28', 'EU15', 'EA', 'EA19', 'EA12', 'EU27_2007']

# %%
import numpy as np
results_compiled_tot = pd.DataFrame()
ratio_compiled_tot = pd.DataFrame()
size_classes= df.size_emp.nunique()
#size= [set(df.size_emp.unique())]
size= df.size_emp.unique()

# columns of countries to be eliminated after sum
cols = ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI','FR', 'HR', 'HU', 'IE', 'IT', 'LT','LU', 'LV', 'MT','NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']

# %%
#loop for the years
for i in range (year_start[0],year_end[0]+1):
    year=i
    #we create two dataframes to store the partial calculations for each year One for the absolute values and another for the rations
    results_compiled = pd.DataFrame()
    ratio_compiled = pd.DataFrame()
    #loop for the classes
    for j in range (0,size_classes):
        #size_sel is the class selected in each step of the loop
        size_sel=[size[j]]
        #we select the rows that have the right size, nace codes, variables and countries ~indicates not in the group
        df_selection=df[df.size_emp.isin(size_sel)&~df.nace_r2.isin(nacedrop)&df.indic_sb.isin(var)&~df.geo.isin(countries_not_selected)]
        #print(size_sel)
        #create a dataframe for the results by transposing the values to columns
        #print(df_selection)
        df_target = pd.pivot_table(df_selection, values=year, index=['nace_r2'],columns=["geo"], aggfunc=np.sum, fill_value=0)#reorde
        #print(df_target)
        df_target['sum'] = df_target[cols].sum(axis=1)#sums the columns of the countries to "sum"
        df_target=df_target.drop(cols, axis=1)#we eliminate the columns with the countries
        #now we can locate columns with 0 and make the substitution with the column "sum" for missing data in the totals
        df_target.loc[df_target['EU27_2020']==0,'EU27_2020'] = df_target['sum']
        moddf_target=df_target.drop('sum', axis=1) #we drop the column "sum"
        weights_target = pd.read_excel("ecosystemweightsextended.xlsx") # upload the ecosystem weights
        weights_target.set_index('NACE_R2', inplace=True)#we use nace as index in the ecosystem weights
        #print(moddf_target)
        #print(" ")
        #index the nace codes for rows
        pd.set_option('display.float_format', lambda x: '%.4f' % x)#this sets decimals to 4 digits
        column_name=str(variable_of_interest)+str(year)+str(size_sel)#we name the colums with the variable name+year+size
        weights_target[variable_of_interest]=weights_target.index.map(moddf_target['EU27_2020'])#look in df_target for the nace and copies the value in EU27_2020 in the corresponding nace row in weights_target
        #we create the table for results using the weights target structure
        results=weights_target.copy()
        
        for i in range(0,14):#we iterate through the rows to multiply ecosystem weights by the value of the variable of interest (stored in weights target)
            results.iloc[:, i]=weights_target.iloc[:, i]*weights_target[variable_of_interest]#we multiply the total value added by the weight for each nace
        results.loc['total'] = results.select_dtypes(pd.np.number).sum() #we add the values of each colum in a row call total
        results = results.drop(variable_of_interest, axis=1)
        results_compiled[column_name]=results.loc['total'] #results compiled is storing the totals for a iteration 
        #ratio_compiled[column_name]=results.loc['total']    
        #sum of the totals
        #results_compiled.loc['total'] = results_compiled.select_dtypes(pd.np.number).sum() 
    #ratio_compiled_tot = pd.concat([results_compiled_tot,results_compiled], axis=1)
    #sum_ratio = pd.DataFrame() #creates 
    for j in range (0,6):#iterates through classes to calculate the ratios
        ratio_compiled[j]=results_compiled.iloc[:,j]/results_compiled.iloc[:,5]
    ratio_compiled_tot = pd.concat([ratio_compiled_tot,ratio_compiled], axis=1)#adds ratio_compiled for each class
    results_compiled_tot = pd.concat([results_compiled_tot,results_compiled], axis=1)#results_compiled_total adds results_compiled for each class   
results_compiled_tot
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                Persons employed - number2011['0-9']  \
# Aerospace & Defence                                                     472540.9248
# Agri-food                                                              1180614.4830
# Construction                                                           8643319.9295
# Cultural and Creative Industries                                       1848168.4207
# Digital                                                                1333679.8318
# Electronics                                                             164024.5837
# Energy - Renewables                                                     109535.0986
# Energy Intensive Industries                                            1027857.9843
# Health                                                                  709214.5302
# Mobility - Transport - Automotive                                      3160088.5934
# Proximity, Social Economy and Civil Security                           2459126.0131
# Retail                                                                10417379.0095
# Textile                                                                 468800.4548
# Tourism                                                                5788515.5720
#
#                                                Persons employed - number2011['10-19']  \
# Aerospace & Defence                                                       228841.5159
# Agri-food                                                                 555177.1476
# Construction                                                             2624789.8400
# Cultural and Creative Industries                                          422782.3615
# Digital                                                                   386891.4216
# Electronics                                                               100895.9558
# Energy - Renewables                                                        51667.7053
# Energy Intensive Industries                                               543836.7123
# Health                                                                    242188.7013
# Mobility - Transport - Automotive                                        1058903.9187
# Proximity, Social Economy and Civil Security                              565511.3708
# Retail                                                                   2683607.2485
# Textile                                                                   245674.2882
# Tourism                                                                  1735433.9471
#
#                                                Persons employed - number2011['20-49']  \
# Aerospace & Defence                                                       355120.0995
# Agri-food                                                                 666814.1170
# Construction                                                             2813771.1264
# Cultural and Creative Industries                                          529520.2855
# Digital                                                                   531664.1058
# Electronics                                                               143576.1806
# Energy - Renewables                                                        79063.3373
# Energy Intensive Industries                                               809000.9207
# Health                                                                    261114.2428
# Mobility - Transport - Automotive                                        1394230.3624
# Proximity, Social Economy and Civil Security                              608479.7479
# Retail                                                                   3016247.7438
# Textile                                                                   360024.9101
# Tourism                                                                  1821265.8016
#
#                                                Persons employed - number2011['50-249']  \
# Aerospace & Defence                                                        873181.7898
# Agri-food                                                                 1412260.6621
# Construction                                                              3761331.4130
# Cultural and Creative Industries                                           847748.8420
# Digital                                                                    976956.7176
# Electronics                                                                382633.0033
# Energy - Renewables                                                        211249.6664
# Energy Intensive Industries                                               1935049.1042
# Health                                                                     539361.8337
# Mobility - Transport - Automotive                                         1792804.9879
# Proximity, Social Economy and Civil Security                               812561.8356
# Retail                                                                    3867710.7357
# Textile                                                                    672715.2263
# Tourism                                                                   1997992.6923
#
#                                                Persons employed - number2011['GE250']  \
# Aerospace & Defence                                                      1947936.4854
# Agri-food                                                                1897097.1819
# Construction                                                             4679537.3560
# Cultural and Creative Industries                                         1073501.2960
# Digital                                                                  2212304.1990
# Electronics                                                               807934.8531
# Energy - Renewables                                                       636395.6031
# Energy Intensive Industries                                              2952246.9750
# Health                                                                   1083781.5901
# Mobility - Transport - Automotive                                        4383948.2593
# Proximity, Social Economy and Civil Security                             1790170.4142
# Retail                                                                   8598484.6526
# Textile                                                                   489498.2064
# Tourism                                                                  3062617.9417
#
#                                                Persons employed - number2011['TOTAL']  \
# Aerospace & Defence                                                      3899193.5881
# Agri-food                                                                5778391.0668
# Construction                                                            22546401.3923
# Cultural and Creative Industries                                         4757858.3175
# Digital                                                                  5476847.5739
# Electronics                                                              1589817.0692
# Energy - Renewables                                                      1091279.4618
# Energy Intensive Industries                                              7320485.4566
# Health                                                                   2828705.7651
# Mobility - Transport - Automotive                                       12145456.9604
# Proximity, Social Economy and Civil Security                             6267187.5045
# Retail                                                                  28604728.0313
# Textile                                                                  2240142.3402
# Tourism                                                                 14384214.5057
#
#                                                Persons employed - number2012['0-9']  \
# Aerospace & Defence                                                     456416.6296
# Agri-food                                                              1110950.1987
# Construction                                                           8536604.0375
# Cultural and Creative Industries                                       1869844.4850
# Digital                                                                1358888.6467
# Electronics                                                             164234.6005
# Energy - Renewables                                                     109436.3605
# Energy Intensive Industries                                             999764.2615
# Health                                                                  704291.6360
# Mobility - Transport - Automotive                                      3113153.2228
# Proximity, Social Economy and Civil Security                           2467466.2248
# Retail                                                                10328778.8438
# Textile                                                                 454631.6159
# Tourism                                                                5771871.4212
#
#                                                Persons employed - number2012['10-19']  \
# Aerospace & Defence                                                       231601.7898
# Agri-food                                                                 564940.8010
# Construction                                                             2548020.2997
# Cultural and Creative Industries                                          426171.0968
# Digital                                                                   397239.2202
# Electronics                                                                97263.4940
# Energy - Renewables                                                        51091.2314
# Energy Intensive Industries                                               507751.3528
# Health                                                                    228826.2139
# Mobility - Transport - Automotive                                        1034414.1622
# Proximity, Social Economy and Civil Security                              563531.8446
# Retail                                                                   2610738.4159
# Textile                                                                   226662.7819
# Tourism                                                                  1742084.2058
#
#                                                Persons employed - number2012['20-49']  \
# Aerospace & Defence                                                       353161.0536
# Agri-food                                                                 671555.6129
# Construction                                                             2739671.7432
# Cultural and Creative Industries                                          527538.7152
# Digital                                                                   542159.0393
# Electronics                                                               145595.4147
# Energy - Renewables                                                        79710.2169
# Energy Intensive Industries                                               790373.7786
# Health                                                                    258024.0126
# Mobility - Transport - Automotive                                        1356662.5805
# Proximity, Social Economy and Civil Security                              610638.6397
# Retail                                                                   2932401.2942
# Textile                                                                   351029.6795
# Tourism                                                                  1848559.8298
#
#                                                Persons employed - number2012['50-249']  \
# Aerospace & Defence                                                        853899.6670
# Agri-food                                                                 1413115.8992
# Construction                                                              3658633.4922
# Cultural and Creative Industries                                           838772.6154
# Digital                                                                   1013237.6636
# Electronics                                                                378253.1600
# Energy - Renewables                                                        211473.9519
# Energy Intensive Industries                                               1916137.7400
# Health                                                                     546712.7794
# Mobility - Transport - Automotive                                         2143580.2288
# Proximity, Social Economy and Civil Security                               817144.5595
# Retail                                                                    3798016.9213
# Textile                                                                    645770.6964
# Tourism                                                                   2056573.4082
#
#                                                ...  \
# Aerospace & Defence                            ...
# Agri-food                                      ...
# Construction                                   ...
# Cultural and Creative Industries               ...
# Digital                                        ...
# Electronics                                    ...
# Energy - Renewables                            ...
# Energy Intensive Industries                    ...
# Health                                         ...
# Mobility - Transport - Automotive              ...
# Proximity, Social Economy and Civil Security   ...
# Retail                                         ...
# Textile                                        ...
# Tourism                                        ...
#
#                                                Persons employed - number2018['20-49']  \
# Aerospace & Defence                                                       379445.9703
# Agri-food                                                                 711878.5622
# Construction                                                             2987319.1897
# Cultural and Creative Industries                                          509076.1548
# Digital                                                                   645211.8300
# Electronics                                                               149493.7774
# Energy - Renewables                                                        80178.4588
# Energy Intensive Industries                                               745763.8006
# Health                                                                    281756.5509
# Mobility - Transport - Automotive                                        1331955.8833
# Proximity, Social Economy and Civil Security                              720636.0962
# Retail                                                                   2970553.9464
# Textile                                                                   339325.0627
# Tourism                                                                  2419939.5212
#
#                                                Persons employed - number2018['50-249']  \
# Aerospace & Defence                                                        845381.6917
# Agri-food                                                                 1389535.7832
# Construction                                                              3790017.3186
# Cultural and Creative Industries                                           781842.2470
# Digital                                                                   1154517.9501
# Electronics                                                                359839.9762
# Energy - Renewables                                                        200094.2291
# Energy Intensive Industries                                               1801630.1203
# Health                                                                     556009.4412
# Mobility - Transport - Automotive                                         2179093.9641
# Proximity, Social Economy and Civil Security                               918677.3464
# Retail                                                                    3797500.9567
# Textile                                                                    586381.1010
# Tourism                                                                   2569536.2438
#
#                                                Persons employed - number2018['GE250']  \
# Aerospace & Defence                                                      2349903.6179
# Agri-food                                                                2642757.6222
# Construction                                                             6061423.3814
# Cultural and Creative Industries                                         1378745.9228
# Digital                                                                  2992401.4795
# Electronics                                                               951079.3766
# Energy - Renewables                                                       734940.5915
# Energy Intensive Industries                                              3731253.9414
# Health                                                                   1568595.6576
# Mobility - Transport - Automotive                                        5839521.6500
# Proximity, Social Economy and Civil Security                             2315905.8257
# Retail                                                                  10418517.9354
# Textile                                                                   547282.5404
# Tourism                                                                  4062593.2422
#
#                                                Persons employed - number2018['TOTAL']  \
# Aerospace & Defence                                                      4263316.7647
# Agri-food                                                                6389974.1130
# Construction                                                            24712064.9687
# Cultural and Creative Industries                                         5166237.7916
# Digital                                                                  6880031.4434
# Electronics                                                              1671494.1335
# Energy - Renewables                                                      1213243.3897
# Energy Intensive Industries                                              7692865.0665
# Health                                                                   3375467.6056
# Mobility - Transport - Automotive                                       13690928.4635
# Proximity, Social Economy and Civil Security                             7164799.2719
# Retail                                                                  29513258.7120
# Textile                                                                  2150564.4130
# Tourism                                                                 17714998.1235
#
#                                                Persons employed - number2019['0-9']  \
# Aerospace & Defence                                                     450512.1411
# Agri-food                                                              1100068.7964
# Construction                                                           9185656.9147
# Cultural and Creative Industries                                       2022763.0954
# Digital                                                                1650792.2366
# Electronics                                                             163617.1651
# Energy - Renewables                                                     147641.3214
# Energy Intensive Industries                                             906067.5916
# Health                                                                  739514.4190
# Mobility - Transport - Automotive                                      3216664.0313
# Proximity, Social Economy and Civil Security                           2482341.2263
# Retail                                                                 9362241.5637
# Textile                                                                 428978.3884
# Tourism                                                                6233989.0602
#
#                                                Persons employed - number2019['10-19']  \
# Aerospace & Defence                                                       224572.9464
# Agri-food                                                                 548482.6472
# Construction                                                             2936955.9888
# Cultural and Creative Industries                                          430027.4321
# Digital                                                                   452117.4679
# Electronics                                                                89885.2282
# Energy - Renewables                                                        51527.5742
# Energy Intensive Industries                                               459699.8730
# Health                                                                    228268.8797
# Mobility - Transport - Automotive                                        1060494.0703
# Proximity, Social Economy and Civil Security                              694425.5237
# Retail                                                                   2672027.1859
# Textile                                                                   215254.7736
# Tourism                                                                  2416853.0699
#
#                                                Persons employed - number2019['20-49']  \
# Aerospace & Defence                                                       381045.6090
# Agri-food                                                                 730147.8451
# Construction                                                             3125334.9718
# Cultural and Creative Industries                                          517697.1837
# Digital                                                                   651001.6823
# Electronics                                                               150119.0909
# Energy - Renewables                                                        81410.3115
# Energy Intensive Industries                                               750023.8260
# Health                                                                    288431.3317
# Mobility - Transport - Automotive                                        1340714.5630
# Proximity, Social Economy and Civil Security                              739252.0909
# Retail                                                                   3027166.0080
# Textile                                                                   328322.9183
# Tourism                                                                  2486914.3066
#
#                                                Persons employed - number2019['50-249']  \
# Aerospace & Defence                                                        859251.4166
# Agri-food                                                                 1392045.8766
# Construction                                                              3891297.1502
# Cultural and Creative Industries                                           796591.8048
# Digital                                                                   1181046.9828
# Electronics                                                                363479.9930
# Energy - Renewables                                                        202861.8323
# Energy Intensive Industries                                               1768943.9306
# Health                                                                     561429.4306
# Mobility - Transport - Automotive                                         2191894.4033
# Proximity, Social Economy and Civil Security                               933957.5380
# Retail                                                                    3838388.6207
# Textile                                                                    563082.6930
# Tourism                                                                   2676320.3486
#
#                                                Persons employed - number2019['GE250']  \
# Aerospace & Defence                                                      2351446.9502
# Agri-food                                                                2731535.3364
# Construction                                                             6329348.8119
# Cultural and Creative Industries                                         1418589.6512
# Digital                                                                  3126112.2124
# Electronics                                                               947703.6332
# Energy - Renewables                                                       753451.8048
# Energy Intensive Industries                                              3859458.5617
# Health                                                                   1611747.7222
# Mobility - Transport - Automotive                                        5977381.1472
# Proximity, Social Economy and Civil Security                             2366056.9073
# Retail                                                                  10541668.4183
# Textile                                                                   530545.9165
# Tourism                                                                  4242274.2360
#
#                                                Persons employed - number2019['TOTAL']
# Aerospace & Defence                                                      4284041.4134
# Agri-food                                                                6481948.9825
# Construction                                                            25409820.0489
# Cultural and Creative Industries                                         5230161.4948
# Digital                                                                  7082023.4648
# Electronics                                                              1709880.3066
# Energy - Renewables                                                      1225488.8492
# Energy Intensive Industries                                              7654290.5302
# Health                                                                   3398905.9897
# Mobility - Transport - Automotive                                       13763677.7720
# Proximity, Social Economy and Civil Security                             7263242.5220
# Retail                                                                  29673400.4840
# Textile                                                                  2080548.5812
# Tourism                                                                 18191332.6502
#
# [14 rows x 54 columns]

# %%
ratio_compiled_tot.columns=results_compiled_tot.columns #give the same name to the columns in the ratio
ratio_compiled_tot
# Out:
#                                                Persons employed - number2011['0-9']  \
# Aerospace & Defence                                                          0.1212
# Agri-food                                                                    0.2043
# Construction                                                                 0.3834
# Cultural and Creative Industries                                             0.3884
# Digital                                                                      0.2435
# Electronics                                                                  0.1032
# Energy - Renewables                                                          0.1004
# Energy Intensive Industries                                                  0.1404
# Health                                                                       0.2507
# Mobility - Transport - Automotive                                            0.2602
# Proximity, Social Economy and Civil Security                                 0.3924
# Retail                                                                       0.3642
# Textile                                                                      0.2093
# Tourism                                                                      0.4024
#
#                                                Persons employed - number2011['10-19']  \
# Aerospace & Defence                                                            0.0587
# Agri-food                                                                      0.0961
# Construction                                                                   0.1164
# Cultural and Creative Industries                                               0.0889
# Digital                                                                        0.0706
# Electronics                                                                    0.0635
# Energy - Renewables                                                            0.0473
# Energy Intensive Industries                                                    0.0743
# Health                                                                         0.0856
# Mobility - Transport - Automotive                                              0.0872
# Proximity, Social Economy and Civil Security                                   0.0902
# Retail                                                                         0.0938
# Textile                                                                        0.1097
# Tourism                                                                        0.1206
#
#                                                Persons employed - number2011['20-49']  \
# Aerospace & Defence                                                            0.0911
# Agri-food                                                                      0.1154
# Construction                                                                   0.1248
# Cultural and Creative Industries                                               0.1113
# Digital                                                                        0.0971
# Electronics                                                                    0.0903
# Energy - Renewables                                                            0.0725
# Energy Intensive Industries                                                    0.1105
# Health                                                                         0.0923
# Mobility - Transport - Automotive                                              0.1148
# Proximity, Social Economy and Civil Security                                   0.0971
# Retail                                                                         0.1054
# Textile                                                                        0.1607
# Tourism                                                                        0.1266
#
#                                                Persons employed - number2011['50-249']  \
# Aerospace & Defence                                                             0.2239
# Agri-food                                                                       0.2444
# Construction                                                                    0.1668
# Cultural and Creative Industries                                                0.1782
# Digital                                                                         0.1784
# Electronics                                                                     0.2407
# Energy - Renewables                                                             0.1936
# Energy Intensive Industries                                                     0.2643
# Health                                                                          0.1907
# Mobility - Transport - Automotive                                               0.1476
# Proximity, Social Economy and Civil Security                                    0.1297
# Retail                                                                          0.1352
# Textile                                                                         0.3003
# Tourism                                                                         0.1389
#
#                                                Persons employed - number2011['GE250']  \
# Aerospace & Defence                                                            0.4996
# Agri-food                                                                      0.3283
# Construction                                                                   0.2076
# Cultural and Creative Industries                                               0.2256
# Digital                                                                        0.4039
# Electronics                                                                    0.5082
# Energy - Renewables                                                            0.5832
# Energy Intensive Industries                                                    0.4033
# Health                                                                         0.3831
# Mobility - Transport - Automotive                                              0.3610
# Proximity, Social Economy and Civil Security                                   0.2856
# Retail                                                                         0.3006
# Textile                                                                        0.2185
# Tourism                                                                        0.2129
#
#                                                Persons employed - number2011['TOTAL']  \
# Aerospace & Defence                                                            1.0000
# Agri-food                                                                      1.0000
# Construction                                                                   1.0000
# Cultural and Creative Industries                                               1.0000
# Digital                                                                        1.0000
# Electronics                                                                    1.0000
# Energy - Renewables                                                            1.0000
# Energy Intensive Industries                                                    1.0000
# Health                                                                         1.0000
# Mobility - Transport - Automotive                                              1.0000
# Proximity, Social Economy and Civil Security                                   1.0000
# Retail                                                                         1.0000
# Textile                                                                        1.0000
# Tourism                                                                        1.0000
#
#                                                Persons employed - number2012['0-9']  \
# Aerospace & Defence                                                          0.1167
# Agri-food                                                                    0.1941
# Construction                                                                 0.3845
# Cultural and Creative Industries                                             0.3963
# Digital                                                                      0.2454
# Electronics                                                                  0.1027
# Energy - Renewables                                                          0.1012
# Energy Intensive Industries                                                  0.1410
# Health                                                                       0.2467
# Mobility - Transport - Automotive                                            0.2566
# Proximity, Social Economy and Civil Security                                 0.3933
# Retail                                                                       0.3650
# Textile                                                                      0.2094
# Tourism                                                                      0.3980
#
#                                                Persons employed - number2012['10-19']  \
# Aerospace & Defence                                                            0.0592
# Agri-food                                                                      0.0987
# Construction                                                                   0.1148
# Cultural and Creative Industries                                               0.0903
# Digital                                                                        0.0717
# Electronics                                                                    0.0608
# Energy - Renewables                                                            0.0473
# Energy Intensive Industries                                                    0.0716
# Health                                                                         0.0802
# Mobility - Transport - Automotive                                              0.0853
# Proximity, Social Economy and Civil Security                                   0.0898
# Retail                                                                         0.0923
# Textile                                                                        0.1044
# Tourism                                                                        0.1201
#
#                                                Persons employed - number2012['20-49']  \
# Aerospace & Defence                                                            0.0903
# Agri-food                                                                      0.1173
# Construction                                                                   0.1234
# Cultural and Creative Industries                                               0.1118
# Digital                                                                        0.0979
# Electronics                                                                    0.0911
# Energy - Renewables                                                            0.0737
# Energy Intensive Industries                                                    0.1114
# Health                                                                         0.0904
# Mobility - Transport - Automotive                                              0.1118
# Proximity, Social Economy and Civil Security                                   0.0973
# Retail                                                                         0.1036
# Textile                                                                        0.1617
# Tourism                                                                        0.1275
#
#                                                Persons employed - number2012['50-249']  \
# Aerospace & Defence                                                             0.2183
# Agri-food                                                                       0.2469
# Construction                                                                    0.1648
# Cultural and Creative Industries                                                0.1778
# Digital                                                                         0.1830
# Electronics                                                                     0.2366
# Energy - Renewables                                                             0.1956
# Energy Intensive Industries                                                     0.2702
# Health                                                                          0.1915
# Mobility - Transport - Automotive                                               0.1767
# Proximity, Social Economy and Civil Security                                    0.1302
# Retail                                                                          0.1342
# Textile                                                                         0.2975
# Tourism                                                                         0.1418
#
#                                                ...  \
# Aerospace & Defence                            ...
# Agri-food                                      ...
# Construction                                   ...
# Cultural and Creative Industries               ...
# Digital                                        ...
# Electronics                                    ...
# Energy - Renewables                            ...
# Energy Intensive Industries                    ...
# Health                                         ...
# Mobility - Transport - Automotive              ...
# Proximity, Social Economy and Civil Security   ...
# Retail                                         ...
# Textile                                        ...
# Tourism                                        ...
#
#                                                Persons employed - number2018['20-49']  \
# Aerospace & Defence                                                            0.0890
# Agri-food                                                                      0.1114
# Construction                                                                   0.1209
# Cultural and Creative Industries                                               0.0985
# Digital                                                                        0.0938
# Electronics                                                                    0.0894
# Energy - Renewables                                                            0.0661
# Energy Intensive Industries                                                    0.0969
# Health                                                                         0.0835
# Mobility - Transport - Automotive                                              0.0973
# Proximity, Social Economy and Civil Security                                   0.1006
# Retail                                                                         0.1007
# Textile                                                                        0.1578
# Tourism                                                                        0.1366
#
#                                                Persons employed - number2018['50-249']  \
# Aerospace & Defence                                                             0.1983
# Agri-food                                                                       0.2175
# Construction                                                                    0.1534
# Cultural and Creative Industries                                                0.1513
# Digital                                                                         0.1678
# Electronics                                                                     0.2153
# Energy - Renewables                                                             0.1649
# Energy Intensive Industries                                                     0.2342
# Health                                                                          0.1647
# Mobility - Transport - Automotive                                               0.1592
# Proximity, Social Economy and Civil Security                                    0.1282
# Retail                                                                          0.1287
# Textile                                                                         0.2727
# Tourism                                                                         0.1450
#
#                                                Persons employed - number2018['GE250']  \
# Aerospace & Defence                                                            0.5512
# Agri-food                                                                      0.4136
# Construction                                                                   0.2453
# Cultural and Creative Industries                                               0.2669
# Digital                                                                        0.4349
# Electronics                                                                    0.5690
# Energy - Renewables                                                            0.6058
# Energy Intensive Industries                                                    0.4850
# Health                                                                         0.4647
# Mobility - Transport - Automotive                                              0.4265
# Proximity, Social Economy and Civil Security                                   0.3232
# Retail                                                                         0.3530
# Textile                                                                        0.2545
# Tourism                                                                        0.2293
#
#                                                Persons employed - number2018['TOTAL']  \
# Aerospace & Defence                                                            1.0000
# Agri-food                                                                      1.0000
# Construction                                                                   1.0000
# Cultural and Creative Industries                                               1.0000
# Digital                                                                        1.0000
# Electronics                                                                    1.0000
# Energy - Renewables                                                            1.0000
# Energy Intensive Industries                                                    1.0000
# Health                                                                         1.0000
# Mobility - Transport - Automotive                                              1.0000
# Proximity, Social Economy and Civil Security                                   1.0000
# Retail                                                                         1.0000
# Textile                                                                        1.0000
# Tourism                                                                        1.0000
#
#                                                Persons employed - number2019['0-9']  \
# Aerospace & Defence                                                          0.1052
# Agri-food                                                                    0.1697
# Construction                                                                 0.3615
# Cultural and Creative Industries                                             0.3867
# Digital                                                                      0.2331
# Electronics                                                                  0.0957
# Energy - Renewables                                                          0.1205
# Energy Intensive Industries                                                  0.1184
# Health                                                                       0.2176
# Mobility - Transport - Automotive                                            0.2337
# Proximity, Social Economy and Civil Security                                 0.3418
# Retail                                                                       0.3155
# Textile                                                                      0.2062
# Tourism                                                                      0.3427
#
#                                                Persons employed - number2019['10-19']  \
# Aerospace & Defence                                                            0.0524
# Agri-food                                                                      0.0846
# Construction                                                                   0.1156
# Cultural and Creative Industries                                               0.0822
# Digital                                                                        0.0638
# Electronics                                                                    0.0526
# Energy - Renewables                                                            0.0420
# Energy Intensive Industries                                                    0.0601
# Health                                                                         0.0672
# Mobility - Transport - Automotive                                              0.0771
# Proximity, Social Economy and Civil Security                                   0.0956
# Retail                                                                         0.0900
# Textile                                                                        0.1035
# Tourism                                                                        0.1329
#
#                                                Persons employed - number2019['20-49']  \
# Aerospace & Defence                                                            0.0889
# Agri-food                                                                      0.1126
# Construction                                                                   0.1230
# Cultural and Creative Industries                                               0.0990
# Digital                                                                        0.0919
# Electronics                                                                    0.0878
# Energy - Renewables                                                            0.0664
# Energy Intensive Industries                                                    0.0980
# Health                                                                         0.0849
# Mobility - Transport - Automotive                                              0.0974
# Proximity, Social Economy and Civil Security                                   0.1018
# Retail                                                                         0.1020
# Textile                                                                        0.1578
# Tourism                                                                        0.1367
#
#                                                Persons employed - number2019['50-249']  \
# Aerospace & Defence                                                             0.2006
# Agri-food                                                                       0.2148
# Construction                                                                    0.1531
# Cultural and Creative Industries                                                0.1523
# Digital                                                                         0.1668
# Electronics                                                                     0.2126
# Energy - Renewables                                                             0.1655
# Energy Intensive Industries                                                     0.2311
# Health                                                                          0.1652
# Mobility - Transport - Automotive                                               0.1593
# Proximity, Social Economy and Civil Security                                    0.1286
# Retail                                                                          0.1294
# Textile                                                                         0.2706
# Tourism                                                                         0.1471
#
#                                                Persons employed - number2019['GE250']  \
# Aerospace & Defence                                                            0.5489
# Agri-food                                                                      0.4214
# Construction                                                                   0.2491
# Cultural and Creative Industries                                               0.2712
# Digital                                                                        0.4414
# Electronics                                                                    0.5543
# Energy - Renewables                                                            0.6148
# Energy Intensive Industries                                                    0.5042
# Health                                                                         0.4742
# Mobility - Transport - Automotive                                              0.4343
# Proximity, Social Economy and Civil Security                                   0.3258
# Retail                                                                         0.3553
# Textile                                                                        0.2550
# Tourism                                                                        0.2332
#
#                                                Persons employed - number2019['TOTAL']
# Aerospace & Defence                                                            1.0000
# Agri-food                                                                      1.0000
# Construction                                                                   1.0000
# Cultural and Creative Industries                                               1.0000
# Digital                                                                        1.0000
# Electronics                                                                    1.0000
# Energy - Renewables                                                            1.0000
# Energy Intensive Industries                                                    1.0000
# Health                                                                         1.0000
# Mobility - Transport - Automotive                                              1.0000
# Proximity, Social Economy and Civil Security                                   1.0000
# Retail                                                                         1.0000
# Textile                                                                        1.0000
# Tourism                                                                        1.0000
#
# [14 rows x 54 columns]

# %%
#save to file to calculate ration
fileratio="ratioSME-"+ variable_of_interest
filename = "%s.xlsx" % fileratio
ratio_compiled_tot.to_excel(filename)

# %%
#results_compiled_tot.loc['total'] = results_compiled_tot.select_dtypes(pd.np.number).sum()

# %%
#results_compiled_tot

# %%
#save to file
#filename = "%s.xlsx" % variable_of_interest
#results_compiled_tot.to_excel(filename)
