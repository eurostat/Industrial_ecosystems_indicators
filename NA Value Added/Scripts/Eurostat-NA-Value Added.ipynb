# %%
# pandas
import pandas as pd

# %%
import PySimpleGUI as sg
def selection(option):
    #sg.theme('DarkAmber')   # Add a touch of color
    #select the variable we want to calculate
    options = option

    # All the stuff inside your window.
    layout = [ 
            [sg.Text('Select one->'), sg.Listbox(options,select_mode=sg.LISTBOX_SELECT_MODE_SINGLE,size=(20,len(options)))],
            [sg.Button('Ok'), sg.Button('Cancel')]
        ]

    # Create the Window
    window = sg.Window('Make your choice', layout)

    # Event Loop to process "events" and get the "values" of the input
    while True:
        event, values = window.read()
        print( f"event={event}" )
        if event is None or event == 'Ok' or event == 'Cancel': # if user closes window or clicks cancel
            break
        
    # close  the window        
    window.close()

    if event == "Cancel":
        print( "You cancelled" )
    else:
        print('You entered ', values[0])
        sg.popup( f"You selected {values[0]}" )        
    return values

# %%
#list of databases NA
datanames = pd.read_excel("datanames.xlsx")
datanames
# Out:
#                                          description       datanames
# 0  National accounts aggregates by industry (up t...     nama_10_a64
# 1  Gross capital formation by industry (up to NAC...  nama_10_a64_p5
# 2  National accounts employment data by industry ...   nama_10_a64_e

# %%
#Put the number of the database
database_selection=0
#change the number to select another database
database_sel= datanames.iloc[database_selection]["datanames"]
database_sel
# Out:
# 'nama_10_a64'

# %%
#nama_10_a64 National accounts aggregates by industry (up to NACE A*64)
#NAMA_10_A64_P5 Gross capital formation by industry (up to NACE A*64)
#National accounts employment data by industry (up to NACE A*64)

import eurostat
df = eurostat.get_data_df(database_sel, flags=False)
df
# Out:
#               unit nace_r2 na_item geo\time  2021    2020    2019    2018  \
# 0       CLV05_MEUR       A     B1G       AL   NaN  1849.6  1824.9  1813.6
# 1       CLV05_MEUR       A     B1G       AT   NaN  3820.3  3940.9  3945.2
# 2       CLV05_MEUR       A     B1G       BE   NaN  2541.5  2727.7  2703.1
# 3       CLV05_MEUR       A     B1G       BG   NaN  1498.3  1549.4  1488.4
# 4       CLV05_MEUR       A     B1G       CH   NaN  2744.5  2804.2  3002.4
# ...            ...     ...     ...      ...   ...     ...     ...     ...
# 233517    PYP_MNAC       U    P51C       RO   NaN     0.0     0.0     0.0
# 233518    PYP_MNAC       U    P51C       SE   NaN     0.0     0.0     0.0
# 233519    PYP_MNAC       U    P51C       SI   NaN     0.0     0.0     0.0
# 233520    PYP_MNAC       U    P51C       SK   NaN     0.0     0.0     0.0
# 233521    PYP_MNAC       U    P51C       UK   NaN     NaN     NaN     NaN
#
#           2017    2016  ...  1984  1983  1982  1981  1980  1979  1978  1977  \
# 0       1792.5  1777.6  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       3803.9  3615.5  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       2997.0  2872.1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       1518.5  1400.1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       2766.7  2855.9  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 233517     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 233518     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 233519     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 233520     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 233521     NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1976  1975
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# ...      ...   ...
# 233517   NaN   NaN
# 233518   NaN   NaN
# 233519   NaN   NaN
# 233520   NaN   NaN
# 233521   NaN   NaN
#
# [233522 rows x 51 columns]

# %%
df.columns
# Out:
# Index([    'unit',  'nace_r2',  'na_item', 'geo\time',       2021,       2020,
#              2019,       2018,       2017,       2016,       2015,       2014,
#              2013,       2012,       2011,       2010,       2009,       2008,
#              2007,       2006,       2005,       2004,       2003,       2002,
#              2001,       2000,       1999,       1998,       1997,       1996,
#              1995,       1994,       1993,       1992,       1991,       1990,
#              1989,       1988,       1987,       1986,       1985,       1984,
#              1983,       1982,       1981,       1980,       1979,       1978,
#              1977,       1976,       1975],
#       dtype='object')

# %%
#eliminate columns for years previous to 2011
years =[]
year_start=1975
year_study=2011
for y in range(year_start,year_study): 
    years.append(y)
df=df.drop(years, axis=1)#quitamos todas las columnas de añosque no nos interesan
#rename geo time column to be easier to handle because of the name
df.rename(columns={"geo\\time": "geo"}, inplace=True)
#We can get the unique values of the different variables

# %%
#list of selected variables variabales

dic_unit = eurostat.get_dic('unit') #dictionary for all the unit in eurostat
#print the units in the database
for u in df.unit.unique():
    if u in dic_unit:
        print (u + " -"+dic_unit[u])
#select the unit that we want
unit=selection(df.unit.unique())[0]

print(" ")

dic_item = eurostat.get_dic('na_item') #dictionary for all the unit in eurostat
for item in df.na_item.unique():
    if item in dic_item:
        print (item + " -"+dic_item[item])
naitem=selection(df.na_item.unique())[0]

print(" ")

#determine the variable of interest based on the selection
for item in naitem:
    if item in dic_item:
        variable_of_interest=dic_item[item]
variable_of_interest
# Out:
# CLV05_MEUR -Chain linked volumes (2005), million euro
# CLV05_MNAC -Chain linked volumes (2005), million units of national currency
# CLV10_MEUR -Chain linked volumes (2010), million euro
# CLV10_MNAC -Chain linked volumes (2010), million units of national currency
# CLV15_MEUR -Chain linked volumes (2015), million euro
# CLV15_MNAC -Chain linked volumes (2015), million units of national currency
# CLV_I10 -Chain linked volumes, index 2010=100
# CLV_I15 -Chain linked volumes, index 2015=100
# CLV_PCH_PRE -Chain linked volumes, percentage change on previous period
# CP_MEUR -Current prices, million euro
# CP_MNAC -Current prices, million units of national currency
# PC_TOT -Percentage of total
# PD10_EUR -Price index (implicit deflator), 2010=100, euro
# PD10_NAC -Price index (implicit deflator), 2010=100, national currency
# PD15_NAC -Price index (implicit deflator), 2015=100, national currency
# PD_PCH_PRE_EUR -Price index (implicit deflator), percentage change on previous period, euro
# PD_PCH_PRE_NAC -Price index (implicit deflator), percentage change on previous period, national currency
# PYP_MEUR -Previous year prices, million euro
# PYP_MNAC -Previous year prices, million units of national currency
# event=Ok
# You entered  ['CP_MEUR']
#
# B1G -Value added, gross
# B2A3N -Operating surplus and mixed income, net
# D1 -Compensation of employees
# D11 -Wages and salaries
# D29X39 -Other taxes less other subsidies on production
# P1 -Output
# P2 -Intermediate consumption
# P51C -Consumption of fixed capital
# event=Ok
# You entered  ['B1G']
# 'Value added, gross'

# %%
nacedrop=['O','K66', 'J', 'H', 'C16-C18','A03', 'O-Q', 'E', 'C31-C33', 'M_N', 'J58-J60', 'R-U', 'G', 'K', 'TOTAL', 'L68A', 'A02', 'C22_C23', 'C29_C30',  'B-E', 'G-I', 'N', 'Q', 'R', 'C24_C25','C', 'M69-M71', 'M73-M75', 'U', 'S', 'B', 'M', 'A01', 'K65','K64']
countries_not_selected= ['UK', 'TR', 'AL','IS','LI','NO','CH','UK','ME','MK','AL','RS','TR','BA','EU28','EU15','EA','EA19','EA12']

#we select the rows that have the right unit, nace codes, items and countries
df_selection=df[df.unit.isin(unit)&~df.nace_r2.isin(nacedrop)&df.na_item.isin(naitem)&~df.geo.isin(countries_not_selected)]

# %%
#ratios to divide N80_82 and 31_32. Value Added from SBS
ratios_values = pd.read_excel("ratioCN-Value added at factor cost - million euro.xlsx")
ratios_values.set_index('nace_r2', inplace=True)#nace como índice
ratios_values
# Out:
#          Value added at factor cost - million euro2011  \
# nace_r2
# C31                                           0.398512
# C32                                           0.601488
# N80                                           0.165778
# N81                                           0.462572
# N82                                           0.371650
#
#          Value added at factor cost - million euro2012  \
# nace_r2
# C31                                           0.403322
# C32                                           0.596678
# N80                                           0.162820
# N81                                           0.459438
# N82                                           0.377742
#
#          Value added at factor cost - million euro2013  \
# nace_r2
# C31                                           0.400551
# C32                                           0.599449
# N80                                           0.158483
# N81                                           0.466741
# N82                                           0.374777
#
#          Value added at factor cost - million euro2014  \
# nace_r2
# C31                                           0.398158
# C32                                           0.601842
# N80                                           0.152327
# N81                                           0.463845
# N82                                           0.383828
#
#          Value added at factor cost - million euro2015  \
# nace_r2
# C31                                           0.400751
# C32                                           0.599249
# N80                                           0.157963
# N81                                           0.467105
# N82                                           0.374932
#
#          Value added at factor cost - million euro2016  \
# nace_r2
# C31                                           0.409175
# C32                                           0.590825
# N80                                           0.160093
# N81                                           0.467350
# N82                                           0.372558
#
#          Value added at factor cost - million euro2017  \
# nace_r2
# C31                                           0.388565
# C32                                           0.611435
# N80                                           0.155610
# N81                                           0.469511
# N82                                           0.374879
#
#          Value added at factor cost - million euro2018  \
# nace_r2
# C31                                           0.382716
# C32                                           0.617284
# N80                                           0.145835
# N81                                           0.477816
# N82                                           0.376349
#
#          Value added at factor cost - million euro2019
# nace_r2
# C31                                           0.401069
# C32                                           0.598931
# N80                                           0.145916
# N81                                           0.495916
# N82                                           0.358168

# %%
weights_target = pd.read_excel("ecosystemweights.xlsx")
weights_target
# Out:
#     NACE_R2  Aerospace & Defence  Agri-food  Construction  \
# 0         A             0.000000   1.000000      0.000000
# 1   C10-C12             0.000000   1.000000      0.000000
# 2   C13-C15             0.000000   0.000000      0.000000
# 3       C16             0.000000   0.000000      0.000000
# 4       C17             0.000000   0.000000      0.000000
# 5       C18             0.000000   0.000000      0.000000
# 6       C19             0.000000   0.000000      0.000000
# 7       C20             0.000000   0.000000      0.000000
# 8       C21             0.000000   0.000000      0.000000
# 9       C22             0.000000   0.000000      0.000000
# 10      C23             0.000000   0.000000      0.000000
# 11      C24             0.000000   0.000000      0.000000
# 12      C25             0.097362   0.066168      0.305189
# 13      C26             0.440000   0.000000      0.000000
# 14      C27             0.230000   0.000000      0.000000
# 15      C28             0.067894   0.078244      0.198393
# 16      C29             0.000000   0.000000      0.000000
# 17      C30             0.681044   0.000000      0.000000
# 18      C31             0.000000   0.000000      1.000000
# 19      C32             0.000000   0.000000      0.000000
# 20      C33             0.166456   0.118497      0.155381
# 21        D             0.000000   0.000000      0.000000
# 22      E36             0.017444   0.121809      0.102483
\
# 0                            0.000000
# 1                            0.000000
# 2                            0.000000
# 3                            0.000000
# 4                            0.000000
# 5                            0.000000
# 6                            0.000000
# 7                            0.000000
# 8                            0.000000
# 9                            0.000000
# 10                           0.000000
# 11                           0.000000
# 12                           0.235501
# 13                           0.000000
# 14                           0.025089
# 15                           0.277642
# 16                           1.000000
# 17                           0.318958
# 18                           0.000000
# 19                           0.000000
# 20                           0.165263
# 21                           0.000000
# 22                           0.058200
# 23                           0.098157
# 24                           0.000000
# 25                           1.000000
# 26                           0.000000
# 27                           0.000000
# 28                           0.517742
# 29                           0.777240
# 30                           0.000000
# 31                           0.393612
# 32                           0.000000
# 33                           0.000000
# 34                           0.000000
# 35                           0.000000
# 36                           0.000000
# 37                           0.000000
# 38                           0.000000
# 39                           0.086191
# 40                           0.092899
# 41                           0.129971
# 42                           0.000000
# 43                           0.000000
# 44                           0.085503
# 45                           0.085503
# 46                           0.000000
# 47                           0.000000
# 48                           0.000000
# 49                           0.000000
# 50                           0.000000
# 51                           0.000000
# 52                           0.000000
# 53                           0.000000
# 54                           0.000000
# 55                           0.000000
# 56                           0.000000
# 57                           0.000000
# 58                           0.000000
#
#     Proximity, Social Economy and Civil Security     Retail   Textile  \
# 0                                        0.000000  0.000000  0.000000
# 1                                        0.000000  0.000000  0.000000
# 2                                        0.000000  0.000000  1.000000
# 3                                        0.000000  0.000000  0.000000
# 4                                        0.000000  0.000000  0.000000
# 5                                        0.000000  0.000000  0.000000
# 6                                        0.000000  0.000000  0.000000
# 7                                        0.000000  0.000000  0.000000
# 8                                        0.000000  0.000000  0.000000
# 9                                        0.000000  0.000000  0.000000
# 10                                       0.000000  0.000000  0.000000
# 11                                       0.000000  0.000000  0.000000
# 12                                       0.023466  0.044200  0.008535
# 13                                       0.000000  0.000000  0.000000
# 14                                       0.000000  0.000000  0.000000
# 15                                       0.029954  0.057346  0.009986
# 16                                       0.000000  0.000000  0.000000
# 17                                       0.000000  0.000000  0.000000
# 18                                       0.000000  0.000000  0.000000
# 19                                       0.000000  0.000000  0.000000
# 20                                       0.035659  0.064677  0.009670
# 21                                       0.000000  0.000000  0.000000
# 22                                       0.076530  0.074141  0.012856
# 23                                       0.053702  0.077560  0.014370
# 24                                       0.000000  0.000000  0.000000
# 25                                       0.000000  0.000000  0.000000
# 26                                       0.000000  1.000000  0.000000
# 27                                       0.155000  1.000000  0.000000
# 28                                       0.000000  0.000000  0.000000
# 29                                       0.000000  0.000000  0.000000
# 30                                       0.000000  0.000000  0.000000
# 31                                       0.000000  0.000000  0.000000
# 32                                       0.000000  1.000000  0.000000
# 33                                       0.140000  0.000000  0.000000
# 34                                       0.000000  0.000000  0.000000
# 35                                       0.000000  0.000000  0.000000
# 36                                       0.000000  0.000000  0.000000
# 37                                       0.000000  0.000000  0.000000
# 38                                       0.083600  0.000000  0.000000
# 39                                       0.057233  0.134521  0.011523
# 40                                       0.044152  0.080038  0.011156
# 41                                       0.046536  0.081408  0.011505
# 42                                       0.000000  0.000000  0.000000
# 43                                       0.000000  0.000000  0.000000
# 44                                       0.061228  0.126924  0.009894
# 45                                       0.061228  0.126924  0.009894
# 46                                       0.000000  0.000000  0.000000
# 47                                       0.000000  0.000000  0.000000
# 48                                       0.280000  0.000000  0.000000
# 49                                       0.110000  0.000000  0.000000
# 50                                       0.000000  0.000000  0.000000
# 51                                       0.000000  0.000000  0.000000
# 52                                       1.000000  0.000000  0.000000
# 53                                       0.000000  0.000000  0.000000
# 54                                       0.000000  0.000000  0.000000
# 55                                       0.000000  0.000000  0.000000
# 56                                       1.000000  0.000000  0.000000
# 57                                       1.000000  0.000000  0.000000
# 58                                       1.000000  0.000000  0.000000
#
#      Tourism
# 0   0.000000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.000000
# 8   0.000000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12  0.036845
# 13  0.000000
# 14  0.000000
# 15  0.050067
# 16  0.000000
# 17  0.000000
# 18  0.000000
# 19  0.000000
# 20  0.071660
# 21  0.000000
# 22  0.104587
# 23  0.071190
# 24  0.000000
# 25  0.000000
# 26  0.000000
# 27  0.000000
# 28  0.445221
# 29  0.222225
# 30  0.907134
# 31  0.000000
# 32  0.000000
# 33  1.000000
# 34  0.000000
# 35  0.000000
# 36  0.000000
# 37  0.000000
# 38  0.000000
# 39  0.067615
# 40  0.054884
# 41  0.048453
# 42  0.000000
# 43  0.000000
# 44  0.082765
# 45  0.082765
# 46  1.000000
# 47  0.000000
# 48  0.000000
# 49  1.000000
# 50  0.000000
# 51  0.000000
# 52  0.000000
# 53  0.660000
# 54  1.000000
# 55  0.000000
# 56  0.000000
# 57  0.000000
# 58  0.000000

# %%
weights_target.NACE_R2.unique()
# Out:
# array(['A', 'C10-C12', 'C13-C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21', 'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29',
#        'C30', 'C31', 'C32', 'C33', 'D', 'E36', 'E37-E39', 'F', 'G45',
#        'G46', 'G47', 'H49', 'H50', 'H51', 'H52', 'H53', 'I', 'J58',
#        'J59_J60', 'J61', 'J62_J63', 'L', 'M69_M70', 'M71', 'M72', 'M73',
#        'M74_M75', 'N77', 'N78', 'N79', 'N80', 'N81', 'N82', 'P', 'Q86',
#        'Q87_Q88', 'R90-R92', 'R93', 'S94', 'S95', 'S96', 'T'],
#       dtype=object)

# %%
# columns of countries to be eliminated
cols = ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI','FR', 'HR', 'HU', 'IE', 'IT', 'LT','LU', 'LV', 'MT','NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']

#create a dataframe for the results
results_compiled = pd.DataFrame()


import numpy as np
#loop to calculate values for years
for j in range (2011,2019):
    year=j
    #we transpose the values for the year selected
    for i in range (year,year+1):
        df_target = pd.pivot_table(df_selection, values=i, index=['nace_r2'],columns=["geo"], aggfunc=np.sum, fill_value=0)#reorde
    df_target['sum'] = df_target[cols].sum(axis=1)#sums the columns of the countries to "sum" 
    df_target=df_target.drop(cols, axis=1)#eliminamos las columnas sumadas de países
    df_target.loc[df_target['EU27_2020']==0,'EU27_2020'] = df_target['sum']#now we can locate columns with 0 and make the substitution with the column "sum"
    moddf_target=df_target.drop('sum', axis=1)#we create a new table 
    #add rows C31,... and assign value with the ratio multiplying by the value of position C31_32
    year_ratio=j-2011
    moddf_target.loc['C31'] = ratios_values.iloc[0][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
    moddf_target.loc['C32'] = ratios_values.iloc[1][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
    moddf_target.loc['N80'] = ratios_values.iloc[2][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
    moddf_target.loc['N81'] = ratios_values.iloc[3][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
    moddf_target.loc['N82'] = ratios_values.iloc[4][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
    #we eliminate rows C31_C32
    moddf_target = moddf_target.drop(['C31_C32', 'N80-N82'])
    pd.set_option('display.float_format', lambda x: '%.4f' % x)
    #cargamos los pesos en el dataframe weight  
    weights_target = pd.read_excel("ecosystemweights.xlsx")
    weights_target.set_index('NACE_R2', inplace=True)#nace como índice
    column_name=str(variable_of_interest)+str(year)
    weights_target[variable_of_interest]=weights_target.index.map(moddf_target['EU27_2020'])#busca en df_target el nace y copia el valor de EU27_2020 en la fila del nace the weights_target
    #creamos la matriz de resultados
    results=weights_target
    for i in range(0,14):
        results.iloc[:, i]=weights_target.iloc[:, i]*weights_target[variable_of_interest]#we multiply the total value added by the weight for each nace
    results.loc['total'] = results.select_dtypes(pd.np.number).sum() #we add the values of each colum in a row call total
    results_compiled[column_name]=results.loc['total']
results_compiled = results_compiled.drop(variable_of_interest)
#sum of the totals
results_SMEs = results_compiled.copy()  
results_big = results_compiled.copy()
#results_compiled.loc['total'] = results_compiled.select_dtypes(pd.np.number).sum()
results_compiled
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                Value added, gross2011  \
# Aerospace & Defence                                       224201.7479
# Agri-food                                                 499274.0455
# Construction                                             1028298.8497
# Cultural and Creative Industries                          399421.8890
# Digital                                                   491854.8398
# Electronics                                               126110.6073
# Energy - Renewables                                       108401.1735
# Energy Intensive Industries                               463112.1629
# Health                                                    966372.4054
# Mobility - Transport - Automotive                         731428.0239
# Proximity, Social Economy and Civil Security              658059.6700
# Retail                                                   1145656.2452
# Textile                                                    78641.3433
# Tourism                                                   675324.8561
#
#                                                Value added, gross2012  \
# Aerospace & Defence                                       225525.3915
# Agri-food                                                 503006.7378
# Construction                                             1014641.6594
# Cultural and Creative Industries                          397954.8597
# Digital                                                   495053.2520
# Electronics                                               121983.0503
# Energy - Renewables                                       111632.1476
# Energy Intensive Industries                               454233.6550
# Health                                                    984829.6950
# Mobility - Transport - Automotive                         725414.8335
# Proximity, Social Economy and Civil Security              670629.9715
# Retail                                                   1157365.9057
# Textile                                                    75084.6334
# Tourism                                                   684025.1532
#
#                                                Value added, gross2013  \
# Aerospace & Defence                                       227900.9581
# Agri-food                                                 516200.7255
# Construction                                             1013675.5151
# Cultural and Creative Industries                          400932.7811
# Digital                                                   502334.9854
# Electronics                                               124189.4471
# Energy - Renewables                                       111171.4423
# Energy Intensive Industries                               452163.6153
# Health                                                   1006741.0695
# Mobility - Transport - Automotive                         734157.2101
# Proximity, Social Economy and Civil Security              684872.3683
# Retail                                                   1169164.9001
# Textile                                                    75925.5350
# Tourism                                                   693054.5638
#
#                                                Value added, gross2014  \
# Aerospace & Defence                                       234686.3411
# Agri-food                                                 525467.3745
# Construction                                             1031724.9013
# Cultural and Creative Industries                          406768.6326
# Digital                                                   514759.3317
# Electronics                                               127697.1492
# Energy - Renewables                                       110538.9959
# Energy Intensive Industries                               466220.0677
# Health                                                   1038478.5140
# Mobility - Transport - Automotive                         772188.1728
# Proximity, Social Economy and Civil Security              701474.5017
# Retail                                                   1197573.6298
# Textile                                                    77821.1032
# Tourism                                                   716102.3140
#
#                                                Value added, gross2015  \
# Aerospace & Defence                                       243696.7358
# Agri-food                                                 537273.8716
# Construction                                             1064448.1234
# Cultural and Creative Industries                          421347.8262
# Digital                                                   536662.6557
# Electronics                                               130249.8248
# Energy - Renewables                                       111977.7852
# Energy Intensive Industries                               495052.4571
# Health                                                   1042976.3132
# Mobility - Transport - Automotive                         807492.6232
# Proximity, Social Economy and Civil Security              721961.2766
# Retail                                                   1247871.9723
# Textile                                                    79427.0812
# Tourism                                                   750896.0918
#
#                                                Value added, gross2016  \
# Aerospace & Defence                                       251804.0862
# Agri-food                                                 548103.7215
# Construction                                             1094391.1367
# Cultural and Creative Industries                          431487.3568
# Digital                                                   555952.8256
# Electronics                                               134319.5190
# Energy - Renewables                                       114644.1854
# Energy Intensive Industries                               510503.6212
# Health                                                   1079245.7357
# Mobility - Transport - Automotive                         845391.2120
# Proximity, Social Economy and Civil Security              742466.8215
# Retail                                                   1281874.6415
# Textile                                                    81126.5422
# Tourism                                                   779138.4250
#
#                                                Value added, gross2017  \
# Aerospace & Defence                                       262890.5220
# Agri-food                                                 580962.1696
# Construction                                             1152484.1759
# Cultural and Creative Industries                          448122.1729
# Digital                                                   590881.6920
# Electronics                                               139397.6343
# Energy - Renewables                                       118261.3951
# Energy Intensive Industries                               530084.7445
# Health                                                   1119341.8825
# Mobility - Transport - Automotive                         884438.2321
# Proximity, Social Economy and Civil Security              772729.6025
# Retail                                                   1344277.6471
# Textile                                                    83785.9198
# Tourism                                                   823569.4352
#
#                                                Value added, gross2018
# Aerospace & Defence                                       270631.0360
# Agri-food                                                 587045.3377
# Construction                                             1211143.3209
# Cultural and Creative Industries                          463713.1586
# Digital                                                   629592.9777
# Electronics                                               145008.3986
# Energy - Renewables                                       121884.2339
# Energy Intensive Industries                               538248.7189
# Health                                                   1157740.6884
# Mobility - Transport - Automotive                         903092.0774
# Proximity, Social Economy and Civil Security              795599.2534
# Retail                                                   1388049.5556
# Textile                                                    85311.4767
# Tourism                                                   858553.8247

# %%
#save to file
filename = "%s.xlsx" % variable_of_interest
results_compiled.to_excel(filename)

# %%
#KPI IN PERCENTAGES
#gross value added as % of the gdp
df_gdp = eurostat.get_data_df('nama_10_gdp', flags=False)
df_gdp.columns

#eliminate columns for years previous to 2011
years =[]
year_start=1975
year_study=2011
for y in range(year_start,year_study): 
    years.append(y)
years.append(2020)
years.append(2021)
df_gdp=df_gdp.drop(years, axis=1)

df_gdp.rename(columns={"geo\\time": "geo"}, inplace=True)
geo_gdp=['EU27_2020']
unit_gdp=['CP_MEUR']
item_gdp= ['B1GQ'] 
year_gdp=[]
for y in range(2011,2019): 
    year_gdp.append(y)
df_gdp_selection=df_gdp[df_gdp.unit.isin(unit_gdp)&df_gdp.na_item.isin(item_gdp)&df_gdp.geo.isin(geo_gdp)]

#drop columns of no interest
df_gdp_selection=df_gdp_selection.drop(['unit','na_item'], axis=1)

#set index in geo
df_gdp_selection.set_index('geo', inplace=True)

#we need to reorder the columns in ascending order to match the other database
columns_gdp_selection = df_gdp_selection.columns
columns_gdp_selection= columns_gdp_selection.sort_values(ascending=True)
df_gdp_selection = df_gdp_selection.reindex(columns=columns_gdp_selection)
df_gdp_selection
# Out:
#                    2011          2012          2013          2014  \
# geo
# EU27_2020 11323915.6000 11391843.8000 11520159.1000 11783874.3000
#
#                    2015          2016          2017          2018  \
# geo
# EU27_2020 12214624.0000 12552499.9000 13076032.1000 13531537.0000
#
#                    2019
# geo
# EU27_2020 14017173.6000

# %%
#we create a table to store the new values Gross Added Value as % of gdp
value_gdp=results_compiled.copy()

num_col_result=len(results_compiled.columns)

#iteration to calculate the values
for i in range(0,num_col_result):
    value_gdp.iloc[:,i]= results_compiled.iloc[:, i]*100/df_gdp_selection.iloc[0, i]
value_gdp=value_gdp.add_suffix('-percentage gdp')
value_gdp
# Out:
#                                                Value added, gross2011-percentage gdp  \
# Aerospace & Defence                                                           1.9799
# Agri-food                                                                     4.4090
# Construction                                                                  9.0808
# Cultural and Creative Industries                                              3.5272
# Digital                                                                       4.3435
# Electronics                                                                   1.1137
# Energy - Renewables                                                           0.9573
# Energy Intensive Industries                                                   4.0897
# Health                                                                        8.5339
# Mobility - Transport - Automotive                                             6.4591
# Proximity, Social Economy and Civil Security                                  5.8112
# Retail                                                                       10.1171
# Textile                                                                       0.6945
# Tourism                                                                       5.9637
#
#                                                Value added, gross2012-percentage gdp  \
# Aerospace & Defence                                                           1.9797
# Agri-food                                                                     4.4155
# Construction                                                                  8.9067
# Cultural and Creative Industries                                              3.4933
# Digital                                                                       4.3457
# Electronics                                                                   1.0708
# Energy - Renewables                                                           0.9799
# Energy Intensive Industries                                                   3.9874
# Health                                                                        8.6450
# Mobility - Transport - Automotive                                             6.3678
# Proximity, Social Economy and Civil Security                                  5.8869
# Retail                                                                       10.1596
# Textile                                                                       0.6591
# Tourism                                                                       6.0045
#
#                                                Value added, gross2013-percentage gdp  \
# Aerospace & Defence                                                           1.9783
# Agri-food                                                                     4.4808
# Construction                                                                  8.7991
# Cultural and Creative Industries                                              3.4803
# Digital                                                                       4.3605
# Electronics                                                                   1.0780
# Energy - Renewables                                                           0.9650
# Energy Intensive Industries                                                   3.9250
# Health                                                                        8.7390
# Mobility - Transport - Automotive                                             6.3728
# Proximity, Social Economy and Civil Security                                  5.9450
# Retail                                                                       10.1489
# Textile                                                                       0.6591
# Tourism                                                                       6.0160
#
#                                                Value added, gross2014-percentage gdp  \
# Aerospace & Defence                                                           1.9916
# Agri-food                                                                     4.4592
# Construction                                                                  8.7554
# Cultural and Creative Industries                                              3.4519
# Digital                                                                       4.3683
# Electronics                                                                   1.0837
# Energy - Renewables                                                           0.9381
# Energy Intensive Industries                                                   3.9564
# Health                                                                        8.8127
# Mobility - Transport - Automotive                                             6.5529
# Proximity, Social Economy and Civil Security                                  5.9528
# Retail                                                                       10.1628
# Textile                                                                       0.6604
# Tourism                                                                       6.0770
#
#                                                Value added, gross2015-percentage gdp  \
# Aerospace & Defence                                                           1.9951
# Agri-food                                                                     4.3986
# Construction                                                                  8.7145
# Cultural and Creative Industries                                              3.4495
# Digital                                                                       4.3936
# Electronics                                                                   1.0663
# Energy - Renewables                                                           0.9168
# Energy Intensive Industries                                                   4.0529
# Health                                                                        8.5388
# Mobility - Transport - Automotive                                             6.6109
# Proximity, Social Economy and Civil Security                                  5.9106
# Retail                                                                       10.2162
# Textile                                                                       0.6503
# Tourism                                                                       6.1475
#
#                                                Value added, gross2016-percentage gdp  \
# Aerospace & Defence                                                           2.0060
# Agri-food                                                                     4.3665
# Construction                                                                  8.7185
# Cultural and Creative Industries                                              3.4375
# Digital                                                                       4.4290
# Electronics                                                                   1.0701
# Energy - Renewables                                                           0.9133
# Energy Intensive Industries                                                   4.0669
# Health                                                                        8.5979
# Mobility - Transport - Automotive                                             6.7348
# Proximity, Social Economy and Civil Security                                  5.9149
# Retail                                                                       10.2121
# Textile                                                                       0.6463
# Tourism                                                                       6.2070
#
#                                                Value added, gross2017-percentage gdp  \
# Aerospace & Defence                                                           2.0105
# Agri-food                                                                     4.4430
# Construction                                                                  8.8137
# Cultural and Creative Industries                                              3.4271
# Digital                                                                       4.5188
# Electronics                                                                   1.0661
# Energy - Renewables                                                           0.9044
# Energy Intensive Industries                                                   4.0539
# Health                                                                        8.5603
# Mobility - Transport - Automotive                                             6.7638
# Proximity, Social Economy and Civil Security                                  5.9095
# Retail                                                                       10.2805
# Textile                                                                       0.6408
# Tourism                                                                       6.2983
#
#                                                Value added, gross2018-percentage gdp
# Aerospace & Defence                                                           2.0000
# Agri-food                                                                     4.3383
# Construction                                                                  8.9505
# Cultural and Creative Industries                                              3.4269
# Digital                                                                       4.6528
# Electronics                                                                   1.0716
# Energy - Renewables                                                           0.9007
# Energy Intensive Industries                                                   3.9777
# Health                                                                        8.5559
# Mobility - Transport - Automotive                                             6.6740
# Proximity, Social Economy and Civil Security                                  5.8796
# Retail                                                                       10.2579
# Textile                                                                       0.6305
# Tourism                                                                       6.3448

# %%
#save to file
filename = "%s.xlsx" % (variable_of_interest+str('-percentage over GDP'))
value_gdp.to_excel(filename)

# %%
#KPI IN PERCENTAGES

#create the new table and drop the first column
percent_change=results_compiled.copy() 
percent_change=percent_change.drop(results_compiled.columns[0], axis=1)

#calculate the new number of columns
num_col_percent=len(percent_change.columns)

#iteration to calculate the values
for i in range(0,num_col_percent):
    percent_change.iloc[:,i]= (results_compiled.iloc[:, i+1]-results_compiled.iloc[:, i])*100/results_compiled.iloc[:, i]
percent_change=percent_change.add_suffix('-percentage change')
percent_change
# Out:
#                                                Value added, gross2012-percentage change  \
# Aerospace & Defence                                                              0.5904
# Agri-food                                                                        0.7476
# Construction                                                                    -1.3281
# Cultural and Creative Industries                                                -0.3673
# Digital                                                                          0.6503
# Electronics                                                                     -3.2730
# Energy - Renewables                                                              2.9806
# Energy Intensive Industries                                                     -1.9171
# Health                                                                           1.9100
# Mobility - Transport - Automotive                                               -0.8221
# Proximity, Social Economy and Civil Security                                     1.9102
# Retail                                                                           1.0221
# Textile                                                                         -4.5227
# Tourism                                                                          1.2883
#
#                                                Total employment domestic concept2016  \
# Aerospace & Defence                                                        4232.3492
# Agri-food                                                                 16335.1493
# Construction                                                              24470.2145
# Cultural and Creative Industries                                           7987.5126
# Digital                                                                    6285.3453
# Electronics                                                                1705.1736
# Energy - Renewables                                                        1151.0824
# Energy Intensive Industries                                                7475.8787
# Health                                                                    24030.3220
# Mobility - Transport - Automotive                                         13610.3702
# Proximity, Social Economy and Civil Security                              22465.8981
# Retail                                                                    29235.0180
# Textile                                                                    2389.8322
# Tourism                                                                   19358.1607
#
#                                                Total employment domestic concept2017  \
# Aerospace & Defence                                                        4282.0791
# Agri-food                                                                 16440.2099
# Construction                                                              24937.6483
# Cultural and Creative Industries                                           8060.1148
# Digital                                                                    6503.7804
# Electronics                                                                1739.6239
# Energy - Renewables                                                        1154.0645
# Energy Intensive Industries                                                7630.4530
# Health                                                                    24490.4620
# Mobility - Transport - Automotive                                         13967.1234
# Proximity, Social Economy and Civil Security                              22822.8987
# Retail                                                                    29553.4616
# Textile                                                                    2405.5338
# Tourism                                                                   19972.6488
#
#                                                Total employment domestic concept2018
# Aerospace & Defence                                                        4355.0176
# Agri-food                                                                 16320.1869
# Construction                                                              25616.2907
# Cultural and Creative Industries                                           8156.2969
# Digital                                                                    6757.1268
# Electronics                                                                1782.3590
# Energy - Renewables                                                        1175.1838
# Energy Intensive Industries                                                7760.8481
# Health                                                                    24917.2995
# Mobility - Transport - Automotive                                         14314.4188
# Proximity, Social Economy and Civil Security                              23184.0119
# Retail                                                                    29755.0784
# Textile                                                                    2387.5233
# Tourism                                                                   20470.0511

# %%
#we create a table to store the new values Gross Added Value as % of gdp
productivity=results_compiled.copy()
num_col_result=len(results_compiled.columns)
#iteration to calculate the values
for i in range(0,num_col_result):
    productivity.iloc[:,i]= results_compiled.iloc[:, i]/employment.iloc[:, i]
productivity=productivity.add_suffix('-productivity')
productivity
# Out:
#                                                Value added, gross2011-productivity  \
# Aerospace & Defence                                                        54.9293
# Agri-food                                                                  28.8359
# Construction                                                               41.7531
# Cultural and Creative Industries                                           50.8333
# Digital                                                                    85.9472
# Electronics                                                                74.9611
# Energy - Renewables                                                        95.7002
# Energy Intensive Industries                                                60.9353
# Health                                                                     43.4080
# Mobility - Transport - Automotive                                          56.7735
# Proximity, Social Economy and Civil Security                               31.1754
# Retail                                                                     39.6399
# Textile                                                                    30.4947
# Tourism                                                                    38.4394
#
#                                                Value added, gross2012-productivity  \
# Aerospace & Defence                                                        55.0136
# Agri-food                                                                  29.2387
# Construction                                                               41.9510
# Cultural and Creative Industries                                           50.8680
# Digital                                                                    85.1560
# Electronics                                                                71.9999
# Energy - Renewables                                                        98.8435
# Energy Intensive Industries                                                60.6501
# Health                                                                     43.8563
# Mobility - Transport - Automotive                                          56.2513
# Proximity, Social Economy and Civil Security                               31.5240
# Retail                                                                     40.1437
# Textile                                                                    29.7155
# Tourism                                                                    38.6873
#
#                                                Value added, gross2013-productivity  \
# Aerospace & Defence                                                        55.8807
# Agri-food                                                                  30.5133
