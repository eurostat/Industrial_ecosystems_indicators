# %%
# pandas
import pandas as pd

# %%
import PySimpleGUI as sg
def selection(option):
    #sg.theme('DarkAmber')   # Add a touch of color
    #select the variable we want to calculate
    options = option

    # All the stuff inside your window.
    layout = [ 
            [sg.Text('Select one->'), sg.Listbox(options,select_mode=sg.LISTBOX_SELECT_MODE_SINGLE,size=(20,len(options)))],
            [sg.Button('Ok'), sg.Button('Cancel')]
        ]

    # Create the Window
    window = sg.Window('Make your choice', layout)

    # Event Loop to process "events" and get the "values" of the input
    while True:
        event, values = window.read()
        print( f"event={event}" )
        if event is None or event == 'Ok' or event == 'Cancel': # if user closes window or clicks cancel
            break
        
    # close  the window        
    window.close()

    if event == "Cancel":
        print( "You cancelled" )
    else:
        print('You entered ', values[0])
        sg.popup( f"You selected {values[0]}" )        
    return values

# %%
#nama_10_a64 National accounts aggregates by industry (up to NACE A*64)
#NAMA_10_A64_P5 Gross capital formation by industry (up to NACE A*64)
#National accounts employment data by industry (up to NACE A*64)

import eurostat
df = eurostat.get_data_df('nama_10_nfa_st', flags=False)
df
# Out:
#               unit nace_r2 asset10 geo\time  2021   2020    2019    2018  \
# 0       CLV15_MEUR       A   N111G       AT   NaN    NaN     NaN     NaN
# 1       CLV15_MEUR       A   N111G       BE   NaN    NaN     NaN     NaN
# 2       CLV15_MEUR       A   N111G       BG   NaN    NaN  2234.0  2027.9
# 3       CLV15_MEUR       A   N111G       CY   NaN    NaN     NaN     NaN
# 4       CLV15_MEUR       A   N111G       CZ   NaN  328.3   318.6   302.7
# ...            ...     ...     ...      ...   ...    ...     ...     ...
# 229753    PYR_MNAC       U   N11ON       NL   NaN    0.0     0.0     0.0
# 229754    PYR_MNAC       U   N11ON       SE   NaN    NaN     NaN     NaN
# 229755    PYR_MNAC       U   N11ON       SI   NaN    0.0     0.0     0.0
# 229756    PYR_MNAC       U   N11ON       SK   NaN    0.0     0.0     0.0
# 229757    PYR_MNAC       U   N11ON       UK   NaN    NaN     0.0     0.0
#
#           2017    2016  ...  1984  1983  1982  1981  1980  1979  1978  1977  \
# 0          NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       1839.3  1668.3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4        292.7   283.9  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...     ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 229753     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 229754     NaN     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 229755     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 229756     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 229757     0.0     0.0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         1976  1975
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
# ...      ...   ...
# 229753   NaN   NaN
# 229754   NaN   NaN
# 229755   NaN   NaN
# 229756   NaN   NaN
# 229757   NaN   NaN
#
# [229758 rows x 51 columns]

# %%
df.columns
# Out:
# Index([    'unit',  'nace_r2',  'asset10', 'geo\time',       2021,       2020,
#              2019,       2018,       2017,       2016,       2015,       2014,
#              2013,       2012,       2011,       2010,       2009,       2008,
#              2007,       2006,       2005,       2004,       2003,       2002,
#              2001,       2000,       1999,       1998,       1997,       1996,
#              1995,       1994,       1993,       1992,       1991,       1990,
#              1989,       1988,       1987,       1986,       1985,       1984,
#              1983,       1982,       1981,       1980,       1979,       1978,
#              1977,       1976,       1975],
#       dtype='object')

# %%
#eliminate columns for years previous to 2011
years =[]
year_start=1975
year_study=2011
for y in range(year_start,year_study): 
    years.append(y)
years.append(2020)
df=df.drop(years, axis=1)#quitamos todas las columnas de añosque no nos interesan
#rename geo time column to be easier to handle because of the name
df.rename(columns={"geo\\time": "geo"}, inplace=True)
#We can get the unique values of the different variables

# %%
asset= df.asset10.unique()
asset
# Out:
# array(['N111G', 'N111N', 'N112G', 'N112N', 'N1131G', 'N1131N', 'N11321G',
#        'N11321N', 'N11322G', 'N11322N', 'N1132G', 'N1132N', 'N115G',
#        'N115N', 'N1171G', 'N1171N', 'N1173G', 'N1173N', 'N117G', 'N117N',
#        'N11G', 'N11KG', 'N11KN', 'N11MG', 'N11MN', 'N11N', 'N11OG',
#        'N11ON'], dtype=object)

# %% [markdown]
# N111G -Dwellings (gross)
# N111N -Dwellings (net)
# N112G -Other buildings and structures (gross)
# N112N -Other buildings and structures (net)
# N1131G -Transport equipment (gross)
# N1131N -Transport equipment (net)
# N11321G -Computer hardware (gross)
# N11321N -Computer hardware (net)
# N11322G -Telecommunications equipment (gross)
# N11322N -Telecommunications equipment (net)
# N1132G -ICT equipment (gross)
# N1132N -ICT equipment (net)
# N115G -Cultivated biological resources (gross)
# N115N -Cultivated biological resources (net)
# N1171G -Research and development (gross)
# N1171N -Research and development (net)
# N1173G -Computer software and databases (gross)
# N1173N -Computer software and databases (net)
# N117G -Intellectual property products (gross)
# N117N -Intellectual property products (net)
# N11G -Total fixed assets (gross)
# N11KG -Total Construction (gross)
# N11KN -Total Construction (net)
# N11MG -Machinery and equipment and weapons systems (gross)
# N11MN -Machinery and equipment and weapons systems (net)
# N11N -Total fixed assets (net)
# N11OG -Other machinery and equipment and weapons systems (gross)
# N11ON -Other machinery and equipment and weapons systems (net)

# %%
dic_asset = eurostat.get_dic('asset10') #dictionary for all the unit in eurostat
dic_asset
# Out:
# {'N1N': 'Produced non-financial assets (net)',
#  'N1ON': 'Fixed assets and inventories (net)',
#  'N11N': 'Total fixed assets (net)',
#  'N11KN': 'Total Construction (net)',
#  'N111N': 'Dwellings (net)',
#  'N112N': 'Other buildings and structures (net)',
#  'N1121N': 'Buildings other than dwellings (net)',
#  'N1122N': 'Other structures (net)',
#  'N11MN': 'Machinery and equipment and weapons systems (net)',
#  'N1131N': 'Transport equipment (net)',
#  'N1132N': 'ICT equipment (net)',
#  'N11321N': 'Computer hardware (net)',
#  'N11322N': 'Telecommunications equipment (net)',
#  'N11ON': 'Other machinery and equipment and weapons systems (net)',
#  'N115N': 'Cultivated biological resources (net)',
#  'N117N': 'Intellectual property products (net)',
#  'N1171N': 'Research and development (net)',
#  'N1172N': 'Mineral exploration and evaluation (net)',
#  'N1173N': 'Computer software and databases (net)',
#  'N1174N': 'Entertainment, literary or artistic originals (net)',
#  'N1179N': 'Other intellectual property products (net)',
#  'N12N': 'Inventories  (net)',
#  'N13N': 'Valuables (net)',
#  'N1MN': 'Inventories and acquisitions less disposals of valuables (net)',
#  'N2N': 'Non-produced non-financial assets (net)',
#  'N21N': 'Natural resources (net)',
#  'N211N': 'Land (net)',
#  'N212N': 'Mineral and energy reserves (net)',
#  'N21ON': 'Non-cultivated biological resources and water resources (net)',
#  'N215N': 'Other natural resources (net)',
#  'N22N': 'Contracts, leases and licences (net)',
#  'N23N': 'Purchases less sales of goodwill and marketing assets (net)',
#  'N1G': 'Produced non-financial assets (gross)',
#  'N1OG': 'Fixed assets and inventories (gross)',
#  'N11G': 'Total fixed assets (gross)',
#  'N11KG': 'Total Construction (gross)',
#  'N111G': 'Dwellings (gross)',
#  'N112G': 'Other buildings and structures (gross)',
#  'N1121G': 'Buildings other than dwellings (gross)',
#  'N1122G': 'Other structures (gross)',
#  'N11MG': 'Machinery and equipment and weapons systems (gross)',
#  'N1131G': 'Transport equipment (gross)',
#  'N1132G': 'ICT equipment (gross)',
#  'N11321G': 'Computer hardware (gross)',
#  'N11322G': 'Telecommunications equipment (gross)',
#  'N11OG': 'Other machinery and equipment and weapons systems (gross)',
#  'N115G': 'Cultivated biological resources (gross)',
#  'N117G': 'Intellectual property products (gross)',
#  'N1171G': 'Research and development (gross)',
#  'N1172G': 'Mineral exploration and evaluation (gross)',
#  'N1173G': 'Computer software and databases (gross)',
#  'N1174G': 'Entertainment, literary or artistic originals (gross)',
#  'N1179G': 'Other intellectual property products (gross)',
#  'N12G': 'Inventories  (gross)',
#  'N13G': 'Valuables (gross)',
#  'N1MG': 'Inventories and acquisitions less disposals of valuables (gross)',
#  'N2G': 'Non-produced non-financial assets (gross)',
#  'N21G': 'Natural resources (gross)',
#  'N211G': 'Land (gross)',
#  'N212G': 'Mineral and energy reserves (gross)',
#  'N21OG': 'Non-cultivated biological resources and water resources (gross)',
#  'N215G': 'Other natural resources (gross)',
#  'N22G': 'Contracts, leases and licences (gross)',
#  'N23G': 'Purchases less sales of goodwill and marketing assets (gross)'}

# %%
#print the units in the database
assets=[]
for u in df.asset10.unique():
    if u in dic_asset:
        assets.append(dic_asset[u])
#select the unit that we want
assets
# Out:
# ['Dwellings (gross)',
#  'Dwellings (net)',
#  'Other buildings and structures (gross)',
#  'Other buildings and structures (net)',
#  'Transport equipment (gross)',
#  'Transport equipment (net)',
#  'Computer hardware (gross)',
#  'Computer hardware (net)',
#  'Telecommunications equipment (gross)',
#  'Telecommunications equipment (net)',
#  'ICT equipment (gross)',
#  'ICT equipment (net)',
#  'Cultivated biological resources (gross)',
#  'Cultivated biological resources (net)',
#  'Research and development (gross)',
#  'Research and development (net)',
#  'Computer software and databases (gross)',
#  'Computer software and databases (net)',
#  'Intellectual property products (gross)',
#  'Intellectual property products (net)',
#  'Total fixed assets (gross)',
#  'Total Construction (gross)',
#  'Total Construction (net)',
#  'Machinery and equipment and weapons systems (gross)',
#  'Machinery and equipment and weapons systems (net)',
#  'Total fixed assets (net)',
#  'Other machinery and equipment and weapons systems (gross)',
#  'Other machinery and equipment and weapons systems (net)']

# %%
df.geo.unique()
# Out:
# array(['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'EE', 'EL', 'ES', 'FI', 'FR',
#        'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'PT', 'SI', 'SK', 'HR', 'NO',
#        'DK', 'HU', 'NL', 'PL', 'RO', 'SE', 'ME', 'UK'], dtype=object)

# %%
df.unit.unique()
# Out:
# array(['CLV15_MEUR', 'CLV15_MNAC', 'CRC_MEUR', 'CRC_MNAC', 'PYR_MEUR',
#        'PYR_MNAC'], dtype=object)

# %% [markdown]
# CLV15_MEUR 	Chain linked volumes (2015), million euro
# 	CLV15_MNAC 	Chain linked volumes (2015), million units of n...
# 	CRC_MEUR 	Current replacement costs, million euro
# 	CRC_MNAC 	Current replacement costs, million units of nat...
# 	PYR_MEUR 	Previous year replacement costs, million euro
# 	PYR_MNAC 	Previous year replacement costs, million units ...

# %%
unit=["CLV15_MEUR"]

# %%
cols = ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'EL', 'ES', 'FI','FR', 'HR', 'HU', 'IE', 'IT', 'LT','LU', 'LV', 'MT','NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
countries= set(cols)

# %%
df.nace_r2.unique()
# Out:
# array(['A', 'A01', 'A02', 'A03', 'B', 'B-E', 'C', 'C10-C12', 'C13-C15',
#        'C16', 'C16-C18', 'C17', 'C18', 'C19', 'C20', 'C21', 'C22',
#        'C22_C23', 'C23', 'C24', 'C24_C25', 'C25', 'C26', 'C27', 'C28',
#        'C29', 'C29_C30', 'C30', 'C31-C33', 'C31_C32', 'C33', 'D', 'E',
#        'E36', 'E37-E39', 'F', 'G', 'G-I', 'G45', 'G46', 'G47', 'H', 'H49',
#        'H50', 'H51', 'H52', 'H53', 'I', 'J', 'J58', 'J58-J60', 'J59_J60',
#        'J61', 'J62_J63', 'K', 'K64', 'K65', 'K66', 'L', 'L68A', 'M',
#        'M69-M71', 'M69_M70', 'M71', 'M72', 'M73', 'M73-M75', 'M74_M75',
#        'M_N', 'N', 'N77', 'N78', 'N79', 'N80-N82', 'O', 'O-Q', 'P', 'Q',
#        'Q86', 'Q87_Q88', 'R', 'R-U', 'R90-R92', 'R93', 'S', 'S94', 'S95',
#        'S96', 'T', 'TOTAL', 'U'], dtype=object)

# %%
weights_target = pd.read_excel("ecosystemweights.xlsx")
weights_target.NACE_R2.unique()
# Out:
# array(['A', 'C10-C12', 'C13-C15', 'C16', 'C17', 'C18', 'C19', 'C20',
#        'C21', 'C22', 'C23', 'C24', 'C25', 'C26', 'C27', 'C28', 'C29',
#        'C30', 'C31', 'C32', 'C33', 'D', 'E36', 'E37-E39', 'F', 'G45',
#        'G46', 'G47', 'H49', 'H50', 'H51', 'H52', 'H53', 'I', 'J58',
#        'J59_J60', 'J61', 'J62_J63', 'L', 'M69_M70', 'M71', 'M72', 'M73',
#        'M74_M75', 'N77', 'N78', 'N79', 'N80', 'N81', 'N82', 'P', 'Q86',
#        'Q87_Q88', 'R90-R92', 'R93', 'S94', 'S95', 'S96', 'T'],
#       dtype=object)

# %%
nace_equal=set(weights_target.NACE_R2.unique())&set(df.nace_r2.unique())
nace_equal
# Out:
# {'A',
#  'C10-C12',
#  'C13-C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C28',
#  'C29',
#  'C30',
#  'C33',
#  'D',
#  'E36',
#  'E37-E39',
#  'F',
#  'G45',
#  'G46',
#  'G47',
#  'H49',
#  'H50',
#  'H51',
#  'H52',
#  'H53',
#  'I',
#  'J58',
#  'J59_J60',
#  'J61',
#  'J62_J63',
#  'L',
#  'M69_M70',
#  'M71',
#  'M72',
#  'M73',
#  'M74_M75',
#  'N77',
#  'N78',
#  'N79',
#  'P',
#  'Q86',
#  'Q87_Q88',
#  'R90-R92',
#  'R93',
#  'S94',
#  'S95',
#  'S96',
#  'T'}

# %%
nace_dif=set(weights_target.NACE_R2.unique())-set(df.nace_r2.unique())
nace_dif
# Out:
# {'C31', 'C32', 'N80', 'N81', 'N82'}

# %%
#ratios to divide N80_82 and 31_32. Value Added from SBS
ratios_values = pd.read_excel("ratioCN-Value added at factor cost - million euro.xlsx")
ratios_values.set_index('nace_r2', inplace=True)#nace como índice
ratios_values
# Out:
#          Value added at factor cost - million euro2011  \
# nace_r2
# C31                                           0.398512
# C32                                           0.601488
# N80                                           0.165778
# N81                                           0.462572
# N82                                           0.371650
#
#          Value added at factor cost - million euro2012  \
# nace_r2
# C31                                           0.403322
# C32                                           0.596678
# N80                                           0.162820
# N81                                           0.459438
# N82                                           0.377742
#
#          Value added at factor cost - million euro2013  \
# nace_r2
# C31                                           0.400551
# C32                                           0.599449
# N80                                           0.158483
# N81                                           0.466741
# N82                                           0.374777
#
#          Value added at factor cost - million euro2014  \
# nace_r2
# C31                                           0.398158
# C32                                           0.601842
# N80                                           0.152327
# N81                                           0.463845
# N82                                           0.383828
#
#          Value added at factor cost - million euro2015  \
# nace_r2
# C31                                           0.400751
# C32                                           0.599249
# N80                                           0.157963
# N81                                           0.467105
# N82                                           0.374932
#
#          Value added at factor cost - million euro2016  \
# nace_r2
# C31                                           0.409175
# C32                                           0.590825
# N80                                           0.160093
# N81                                           0.467350
# N82                                           0.372558
#
#          Value added at factor cost - million euro2017  \
# nace_r2
# C31                                           0.388565
# C32                                           0.611435
# N80                                           0.155610
# N81                                           0.469511
# N82                                           0.374879
#
#          Value added at factor cost - million euro2018  \
# nace_r2
# C31                                           0.382716
# C32                                           0.617284
# N80                                           0.145835
# N81                                           0.477816
# N82                                           0.376349
#
#          Value added at factor cost - million euro2019
# nace_r2
# C31                                           0.390244
# C32                                           0.609756
# N80                                           0.145557
# N81                                           0.490550
# N82                                           0.363893

# %%
nace_include=['C31_C32','N80-N82']
nace_sel=set(nace_equal)|set(nace_include)
nace_sel
# Out:
# {'A',
#  'C10-C12',
#  'C13-C15',
#  'C16',
#  'C17',
#  'C18',
#  'C19',
#  'C20',
#  'C21',
#  'C22',
#  'C23',
#  'C24',
#  'C25',
#  'C26',
#  'C27',
#  'C28',
#  'C29',
#  'C30',
#  'C31_C32',
#  'C33',
#  'D',
#  'E36',
#  'E37-E39',
#  'F',
#  'G45',
#  'G46',
#  'G47',
#  'H49',
#  'H50',
#  'H51',
#  'H52',
#  'H53',
#  'I',
#  'J58',
#  'J59_J60',
#  'J61',
#  'J62_J63',
#  'L',
#  'M69_M70',
#  'M71',
#  'M72',
#  'M73',
#  'M74_M75',
#  'N77',
#  'N78',
#  'N79',
#  'N80-N82',
#  'P',
#  'Q86',
#  'Q87_Q88',
#  'R90-R92',
#  'R93',
#  'S94',
#  'S95',
#  'S96',
#  'T'}

# %%
#we select the rows that have the right unit, nace codes, items and countries
df_selection=df[df.asset10.isin(asset)&df.nace_r2.isin(nace_sel)&df.geo.isin(countries)&df.unit.isin(unit)]
df_selection
# Out:
#              unit nace_r2 asset10 geo  2021    2019    2018    2017    2016  \
# 0      CLV15_MEUR       A   N111G  AT   NaN     NaN     NaN     NaN     NaN
# 1      CLV15_MEUR       A   N111G  BE   NaN     NaN     NaN     NaN     NaN
# 2      CLV15_MEUR       A   N111G  BG   NaN  2234.0  2027.9  1839.3  1668.3
# 3      CLV15_MEUR       A   N111G  CY   NaN     NaN     NaN     NaN     NaN
# 4      CLV15_MEUR       A   N111G  CZ   NaN   318.6   302.7   292.7   283.9
# ...           ...     ...     ...  ..   ...     ...     ...     ...     ...
# 34179  CLV15_MEUR       T   N11ON  LV   NaN     NaN     NaN     NaN     NaN
# 34180  CLV15_MEUR       T   N11ON  MT   NaN     NaN     NaN     NaN     NaN
# 34181  CLV15_MEUR       T   N11ON  NL   NaN     NaN     NaN     NaN     NaN
# 34183  CLV15_MEUR       T   N11ON  SI   NaN     NaN     NaN     NaN     NaN
# 34184  CLV15_MEUR       T   N11ON  SK   NaN     NaN     NaN     NaN     NaN
#
#          2015    2014    2013    2012    2011
# 0         0.0     NaN     NaN     NaN     NaN
# 1         0.0     NaN     NaN     NaN     NaN
# 2      1514.1  1369.6  1239.8  1122.7  1016.0
# 3         0.0     NaN     NaN     NaN     NaN
# 4       313.1   294.8   314.4   305.5   318.8
# ...       ...     ...     ...     ...     ...
# 34179     0.0     NaN     NaN     NaN     NaN
# 34180     0.0     NaN     NaN     NaN     NaN
# 34181     0.0     NaN     NaN     NaN     NaN
# 34183     0.0     NaN     NaN     NaN     NaN
# 34184     0.0     NaN     NaN     NaN     NaN
#
# [17949 rows x 14 columns]

# %%
import numpy as np


for z in range(0,len(asset)):
    #create a dataframe for the results
    results_compiled = pd.DataFrame()
    #print the variable that we are going to calculate
    print(asset[z], assets[z])
    var=[asset[z]]#to pass it to a list to be able to apply isin
    #get the name of the variable and name it as the variable of interest
    variable_of_interest=asset[z]
    df_selection=df[df.asset10.isin(var)&df.nace_r2.isin(nace_sel)&df.geo.isin(countries)&df.unit.isin(unit)]
    if set(df_selection.geo.unique())==set(countries):
        print("No missing countries in the data") 
        #loop to calculate values for years
        for j in range (2011,2020):
            year=j
            #we transpose the values for the year selected
            for i in range (year,year+1):
                df_target = pd.pivot_table(df_selection, values=i, index=['nace_r2'],columns=["geo"], aggfunc=np.sum, fill_value=0)#reorde
            df_target['sum'] = df_target[cols].sum(axis=1)#sums the columns of the countries to "sum" 
            moddf_target = df_target.rename({'sum': 'EU27_2020'}, axis=1)  # rename column
            #add rows C31,... and assign value with the ratio multiplying by the value of position C31_32
            year_ratio=j-2011 
            moddf_target.loc['C31'] = ratios_values.iloc[0][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
            moddf_target.loc['C32'] = ratios_values.iloc[1][year_ratio]*moddf_target.loc['C31_C32','EU27_2020']
            moddf_target.loc['N80'] = ratios_values.iloc[2][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
            moddf_target.loc['N81'] = ratios_values.iloc[3][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
            moddf_target.loc['N82'] = ratios_values.iloc[4][year_ratio]*moddf_target.loc['N80-N82','EU27_2020']
            #we eliminate rows C31_C32
            moddf_target = moddf_target.drop(['C31_C32', 'N80-N82'])
            pd.set_option('display.float_format', lambda x: '%.4f' % x)
            #cargamos los pesos en el dataframe weight  
            weights_target = pd.read_excel("ecosystemweights.xlsx")
            weights_target.set_index('NACE_R2', inplace=True)#nace como índice
            column_name=str(variable_of_interest)+str(year)
            weights_target[variable_of_interest]=weights_target.index.map(moddf_target['EU27_2020'])#busca en df_target el nace y copia el valor de EU27_2020 en la fila del nace the weights_target
            #creamos la matriz de resultados
            results=weights_target
            for i in range(0,14):
                results.iloc[:, i]=weights_target.iloc[:, i]*weights_target[variable_of_interest]#we multiply the total value added by the weight for each nace
            results.loc['total'] = results.select_dtypes(pd.np.number).sum() #we add the values of each colum in a row call total
            results_compiled[column_name]=results.loc['total']
        results_compiled = results_compiled.drop(variable_of_interest)
        #results_compiled.loc['total'] = results_compiled.select_dtypes(pd.np.number).sum()
        display(results_compiled) 
        #save to file
        filename = "%s.xlsx" % variable_of_interest
        results_compiled.to_excel(filename)
    else:
        print("Missing countries in the data:", set(countries)-set(df_selection.geo.unique()))
# Out:
# N111G Dwellings (gross)
# Missing countries in the data: {'SE', 'HR'}
# N111N Dwellings (net)
# No missing countries in the data
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                  N111N2011    N111N2012  \
# Aerospace & Defence                               649.2274     575.2439
# Agri-food                                       29124.5994   18367.6233
# Construction                                   241362.7016  243081.1271
# Cultural and Creative Industries                 2462.8550    1947.6349
# Digital                                           199.4384     202.5127
# Electronics                                        61.8285      62.4166
# Energy - Renewables                               381.8925     378.2072
# Energy Intensive Industries                       675.5152     741.8236
# Health                                           4277.3709    4236.5945
# Mobility - Transport - Automotive                1355.3636    1118.2027
# Proximity, Social Economy and Civil Security  1455165.4601 1462626.6275
# Retail                                          32089.2866   20737.4752
# Textile                                           811.4969     877.4533
# Tourism                                         34662.3606   21428.3469
#
#                                                  N111N2013    N111N2014  \
# Aerospace & Defence                               546.8973     553.1354
# Agri-food                                       11889.9253    7993.1321
# Construction                                   248032.8428  255272.4561
# Cultural and Creative Industries                 1647.8961    1464.9644
# Digital                                           204.6435     205.8746
# Electronics                                        63.2409      63.9805
# Energy - Renewables                               373.0024     367.4336
# Energy Intensive Industries                       819.2086     912.5464
# Health                                           4285.5023    4271.6769
# Mobility - Transport - Automotive                 962.5719     861.3430
# Proximity, Social Economy and Civil Security  1472631.7382 1480797.2520
# Retail                                          13721.3528    9376.7775
# Textile                                           947.8516    1026.4626
# Tourism                                         13608.6119    9085.6045
#
#                                                  N111N2015    N111N2016  \
# Aerospace & Defence                               626.9817     735.8289
# Agri-food                                        5698.9387    4327.4000
# Construction                                   262767.4229  271784.8901
# Cultural and Creative Industries                 1373.8983    1333.5128
# Digital                                           211.2726     210.9939
# Electronics                                        65.7121      67.2720
# Energy - Renewables                               374.6248     379.0374
# Energy Intensive Industries                      1047.9880    1215.5615
# Health                                           4341.6646    4442.4177
# Mobility - Transport - Automotive                 815.4991     791.4935
# Proximity, Social Economy and Civil Security  1492067.0339 1504672.9671
# Retail                                           6665.8648    4967.7243
# Textile                                          1111.7201    1202.3297
# Tourism                                          6532.6421    5374.4961
#
#                                                  N111N2017    N111N2018  \
# Aerospace & Defence                               868.0009    1018.2412
# Agri-food                                        3554.8182    3146.1900
# Construction                                   281475.1987  294311.4073
# Cultural and Creative Industries                 1378.9884    1408.7868
# Retail                                         18330.6445  18646.4782
# Textile                                         1416.1439   1421.4215
# Tourism                                        49608.8940  50074.3827
#
#                                                N1131N2017  N1131N2018  \
# Aerospace & Defence                             4596.4295   4692.2527
# Agri-food                                      39383.7616  40690.0000
# Construction                                   66587.2444  69886.8729
# Cultural and Creative Industries                4100.2394   4221.1989
# Digital                                        15091.0908  15499.1693
# Electronics                                     1431.3163   1479.5918
# Energy - Renewables                             5317.8058   5732.0155
# Energy Intensive Industries                     6874.9646   7287.3859
# Health                                         14089.6036  14363.1447
# Mobility - Transport - Automotive              68707.2613  70302.8115
# Proximity, Social Economy and Civil Security    9658.2999  10084.3073
# Retail                                         19000.4028  19358.6491
# Textile                                         1465.4741   1482.7568
# Tourism                                        51541.4292  52364.3536
#
#                                                N1131N2019
# Aerospace & Defence                             4690.0943
# Agri-food                                      41965.7959
# Construction                                   72109.4513
# Cultural and Creative Industries                4300.0975
# Digital                                        12714.6131
# Electronics                                     1343.3487
# Energy - Renewables                             6042.6240
# Energy Intensive Industries                     7252.5877
# Health                                         13598.8549
# Mobility - Transport - Automotive              70155.3907
# Proximity, Social Economy and Civil Security   10025.9136
# Retail                                         19398.4920
# Textile                                          921.2642
# Tourism                                        54218.8181
# N11321G Computer hardware (gross)
# Missing countries in the data: {'HR', 'PT', 'DK', 'RO', 'SE', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N11321N Computer hardware (net)
# Missing countries in the data: {'HR', 'PT', 'DK', 'RO', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N11322G Telecommunications equipment (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'RO', 'SE', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N11322N Telecommunications equipment (net)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'RO', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N1132G ICT equipment (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'RO', 'SE', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N1132N ICT equipment (net)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'RO', 'BG', 'ES', 'PL', 'IE', 'HU', 'DE'}
# N115G Cultivated biological resources (gross)
# Missing countries in the data: {'SE'}
# N115N Cultivated biological resources (net)
# No missing countries in the data
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                N115N2011  N115N2012  \
# Aerospace & Defence                             248.0945   243.0468
# Agri-food                                     84042.1829 85282.0773
# Construction                                    403.5017   388.2799
# Cultural and Creative Industries                152.7681   147.3020
# Digital                                         270.5321   267.2323
# Electronics                                     136.7141   137.1124
# Energy - Renewables                             593.8259   578.3262
# Energy Intensive Industries                    1155.7158  1125.8541
# Health                                          410.8713   400.9072
# Mobility - Transport - Automotive              1351.0970  1302.7187
# Proximity, Social Economy and Civil Security    137.1935   135.8493
# Retail                                          832.2507   807.1626
# Textile                                          60.2186    58.2878
# Tourism                                        1103.6440  1093.6262
#
#                                                N115N2013  N115N2014  \
# Aerospace & Defence                             242.3676   244.4027
# Agri-food                                     86226.0525 86399.5809
# Construction                                    390.7037   403.0589
# Cultural and Creative Industries                147.6983   145.3147
# Digital                                         268.6059   282.4805
# Electronics                                     138.9671   141.1518
# Energy - Renewables                             565.2508   562.5803
# Energy Intensive Industries                    1114.6359  1123.1881
# Health                                          392.8606   391.4683
# Mobility - Transport - Automotive              1275.7956  1276.6739
# Proximity, Social Economy and Civil Security    135.8495   134.8281
# Retail                                          797.0628   797.9008
# Textile                                          56.6958    56.5067
# Tourism                                        1091.0059  1091.3743
#
#                                                N115N2015  N115N2016  \
# Aerospace & Defence                             242.0575   239.6543
# Agri-food                                     87091.3097 86066.4784
# Construction                                    402.3105   395.4929
# Cultural and Creative Industries                145.9910   142.4896
# Digital                                         282.1693   275.8237
# Electronics                                     142.6517   142.2630
# Energy - Renewables                             549.3187   531.5937
# Energy Intensive Industries                    1106.4640  1091.0379
# Health                                          382.6701   370.5686
# Mobility - Transport - Automotive              1260.6545  1236.2376
# Proximity, Social Economy and Civil Security    133.8068   132.0164
# Retail                                          824.9573   815.7169
# Textile                                          55.7274    54.0995
# Tourism                                        1073.3997  1073.9877
#
#                                                N115N2017  N115N2018  N115N2019
# Aerospace & Defence                             230.6391   223.8674   230.1895
# Agri-food                                     87657.9879 87739.9515 89009.0698
# Construction                                    381.9818   370.8777   389.4900
# Cultural and Creative Industries                137.1856   137.3949   147.3984
# Digital                                         270.2149   258.3902   307.8969
# Electronics                                     142.5133   142.0762   144.0651
# Energy - Renewables                             502.3647   477.1334   473.7558
# Energy Intensive Industries                    1067.7340  1031.0065  1047.7468
# Health                                          355.2413   340.7603   343.5460
# Mobility - Transport - Automotive              1177.8571  1141.9381  1183.6650
# Proximity, Social Economy and Civil Security    132.4873   161.9785   184.5200
# Retail                                          808.9341   789.9754   804.8540
# Textile                                          51.7281    49.5488    53.3287
# Tourism                                        1062.2277  1062.3128  1080.6414
# N1171G Research and development (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'SE', 'ES', 'PL', 'IE'}
# N1171N Research and development (net)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'ES', 'PL', 'IE'}
# N1173G Computer software and databases (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'SE', 'BG', 'ES', 'PL', 'IE', 'MT'}
# N1173N Computer software and databases (net)
# Missing countries in the data: {'HR', 'CY', 'PT', 'DK', 'BG', 'ES', 'PL', 'IE', 'MT'}
# N117G Intellectual property products (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'SE', 'ES', 'IE', 'MT'}
# N117N Intellectual property products (net)
# Missing countries in the data: {'HR', 'CY', 'PT', 'ES', 'IE', 'MT'}
# N11G Total fixed assets (gross)
# Missing countries in the data: {'HR', 'CY', 'PT', 'SE', 'BG'}
# N11KG Total Construction (gross)
# Missing countries in the data: {'SE', 'BG', 'IE'}
# N11KN Total Construction (net)
# Missing countries in the data: {'IE', 'BG'}
# N11MG Machinery and equipment and weapons systems (gross)
# Missing countries in the data: {'SE'}
# N11MN Machinery and equipment and weapons systems (net)
# No missing countries in the data
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#                                                 N11MN2011   N11MN2012  \
# Aerospace & Defence                            34879.4991  35098.9458
# Agri-food                                     366388.5104 368308.5571
# Construction                                  222704.7104 220710.6206
# Cultural and Creative Industries               28495.9741  29249.8175
# Digital                                       107123.1987 107285.5675
# Electronics                                    32068.4139  31479.1529
# Energy - Renewables                           102176.8383 105822.4294
# Energy Intensive Industries                   180299.6659 187140.2680
# Health                                        122755.0582 124652.7834
